# %% [markdown]
# # Tarea 1 Bases de Datos 2023-1 Grupo XX

# %% [markdown]
# ## Integrantes:
# * Gustav Jacobsson - 202290241-8
# * Nombre Integrante 2 - Rol-2

# %% [markdown]
# ## Requisitos para Correr el Notebook
#
# Para poder utilizar este Notebook se debe tener instalado:
# - **Python 3**
# - **Jupyter**
# - La librería **ipython-sql** (Poder ejecutar sql en Jupyter Notebook)
# - PostgreSQL y su conector desde Python(**psycopg2**)
#
# **IMPORTANTE:** Este Jupyter Notebook se conectará a su servicio de Base de Datos PostgreSQL de manera **local**, por lo que **no funcionará correctamente en el entorno Google Collab.**
#
# Para instalar las dependencias, ejecute (**recuerde actualizar pip3**):

# %%
! pip3 install ipython-sql
! pip3 install psycopg2

#Use to generate names
! pip3 install names
# Out:
# Requirement already satisfied: ipython-sql in c:\users\kaled\appdata\local\programs\python\python310\lib\site-packages (0.5.0)
# Requirement already satisfied: sqlparse in c:\users\kaled\appdata\local\programs\python\python310\lib\site-packages (from ipython-sql) (0.4.3)
# Requirement already satisfied: ipython-genutils in c:\users\kaled\appdata\local\programs\python\python310\lib\site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: ipython in c:\users\kaled\appdata\local\programs\python\python310\lib\site-packages (from ipython-sql) (8.12.0)
# Requirement already satisfied: six in c:\users\kaled\appdata\local\programs\python\python310\lib\site-packages (from ipython-sql) (1.16.0)
# Requirement already satisfied: prettytable in c:\users\kaled\appdata\local\programs\python\python310\lib\site-packages (from ipython-sql) (3.7.0)
# Requirement already satisfied: sqlalchemy>=2.0 in c:\users\kaled\appdata\local\programs\python\python310\lib\site-packages (from ipython-sql) (2.0.9)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\kaled\appdata\local\programs\python\python310\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (2.0.2)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\kaled\appdata\local\programs\python\python310\lib\site-packages (from sqlalchemy>=2.0->ipython-sql) (4.5.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\kaled\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (0.18.2)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\kaled\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (3.0.38)
# Requirement already satisfied: colorama in c:\users\kaled\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (0.4.6)
# Requirement already satisfied: backcall in c:\users\kaled\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (0.2.0)
# Requirement already satisfied: decorator in c:\users\kaled\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (5.1.1)
# Requirement already satisfied: pickleshare in c:\users\kaled\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (0.7.5)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\kaled\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (2.14.0)
# Requirement already satisfied: traitlets>=5 in c:\users\kaled\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (5.9.0)
# Requirement already satisfied: matplotlib-inline in c:\users\kaled\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (0.1.6)
# Requirement already satisfied: stack-data in c:\users\kaled\appdata\local\programs\python\python310\lib\site-packages (from ipython->ipython-sql) (0.6.2)
# Requirement already satisfied: wcwidth in c:\users\kaled\appdata\local\programs\python\python310\lib\site-packages (from prettytable->ipython-sql) (0.2.6)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\kaled\appdata\local\programs\python\python310\lib\site-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.3)
# Requirement already satisfied: pure-eval in c:\users\kaled\appdata\local\programs\python\python310\lib\site-packages (from stack-data->ipython->ipython-sql) (0.2.2)
# Requirement already satisfied: executing>=1.2.0 in c:\users\kaled\appdata\local\programs\python\python310\lib\site-packages (from stack-data->ipython->ipython-sql) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\kaled\appdata\local\programs\python\python310\lib\site-packages (from stack-data->ipython->ipython-sql) (2.2.1)
# [notice] A new release of pip available: 22.2.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: psycopg2 in c:\users\kaled\appdata\local\programs\python\python310\lib\site-packages (2.9.6)
# [notice] A new release of pip available: 22.2.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: names in c:\users\kaled\appdata\local\programs\python\python310\lib\site-packages (0.3.0)
# [notice] A new release of pip available: 22.2.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## Importar dependencias

# %%
from datetime import datetime
import random as r
import names

#Librerías para PostgreSQL
import psycopg2

# %% [markdown]
# Para conectarse a la base de datos, completen los datos relevantes en la variable DATABASE_URL.
#
# * Cambie `user` por el usuario que utilizó en Postgres para acceder a la Base de Datos. Por defecto `postgres`.
# * Cambie `password` por la contraseña de dicho usuario. **Recuerde borrarla antes de entregar su tarea.**
# * Cambie `port` por el puerto en que se ejecuta su servicio de Base de Datos. Por defecto `5432`.
# * Cambie `database` por el nombre de la BD (Schema) que creó en Postgres.
#
# Ejemplo: `postgresql://postgres:pass_segura@localhost:5432/tarea-bd`

# %%
# %reload_ext sql
# %env DATABASE_URL=postgresql://postgres:papelucho1@localhost:5432/Tarea1DB
# Out:
# env: DATABASE_URL=postgresql://postgres:papelucho1@localhost:5432/Tarea1DB

# %% [markdown]
# Para conectarse de forma declarativa a la Base de Datos, utilice el siguiente código:

# %%
#Recuerde cambiar los valores de USER, DBNAME y PASSWORD por los mismos de la celda superior.
connection = psycopg2.connect(
   host="localhost",
   user="postgres",
   dbname='Tarea1DB',
   password="papelucho1"
)

print(connection)
cursor = connection.cursor()
# Out:
# <connection object at 0x0000029553DDCF20; dsn: 'user=postgres password=xxx dbname=Tarea1DB host=localhost', closed: 0>

# %% [markdown]
# ## Crear tablas (36 pts.)
#
# Aquí inserta el código SQL que creara las tablas de la base de datos:

# %% [markdown]
# ### Tabla "facciones" (6 pts)

# %%
# %%sql CREATE TABLE facciones(
# 	id INTEGER PRIMARY KEY GENERATED ALWAYS AS IDENTITY,
# 	nombre VARCHAR(45) NOT NULL,
# 	descripcion VARCHAR(45) NOT NULL
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/Tarea1DB
# Done.
# []

# %% [markdown]
# ### Tabla "trabajos" (6 pts)

# %%
# %%sql CREATE TABLE trabajos(
# 	id INTEGER PRIMARY KEY GENERATED ALWAYS AS IDENTITY,
# 	nombre VARCHAR(45) NOT NULL,
# 	descripcion VARCHAR(45) NOT NULL,
#     sueldo INTEGER NOT NULL
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/Tarea1DB
# Done.
# []

# %% [markdown]
# ### Tabla "personas" (6 pts)

# %%
# %%sql CREATE TABLE personas(
# 	id INTEGER PRIMARY KEY GENERATED ALWAYS AS IDENTITY,
# 	nombre VARCHAR(45) NOT NULL,
#     apellidos VARCHAR(45) NOT NULL,
#     fecha_nacimiento DATE NOT NULL,
# 	infectado BOOL NOT NULL,
#     conyugue INTEGER,
#     FOREIGN KEY (conyugue) REFERENCES personas (id)
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/Tarea1DB
# Done.
# []

# %% [markdown]
# ### Tabla "cuentas_bancarias" (6 pts)

# %%
# %%sql CREATE TABLE cuentas_bancarias(
# 	id INTEGER PRIMARY KEY GENERATED ALWAYS AS IDENTITY,
# 	tipo_de_cuenta VARCHAR(45) NOT NULL,
# 	banco VARCHAR(45) NOT NULL,
#     saldo INTEGER NOT NULL,
#     id_persona INTEGER NOT NULL,
#     FOREIGN KEY (id_persona) REFERENCES personas (id)
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/Tarea1DB
# Done.
# []

# %% [markdown]
# ### Tabla "persona_pertenece_faccion" (6 pts)

# %%
# %%sql CREATE TABLE persona_pertenece_faccion(
# 	id_persona INTEGER,
#     id_faccion INTEGER,
#     FOREIGN KEY (id_persona) REFERENCES personas(id),
#     FOREIGN KEY (id_faccion) REFERENCES facciones(id),
# 	PRIMARY KEY(id_persona,id_faccion)
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/Tarea1DB
# Done.
# []

# %% [markdown]
# ### Tabla "persona_tiene_trabajo" (6 pts)

# %%
# %%sql CREATE TABLE persona_tiene_trabajo(
# 	id_persona INTEGER,
#     id_trabajo INTEGER,
#     estado BOOL NOT NULL,
#     ultima_vez_realizado TIMESTAMP NOT NULL,
#     FOREIGN KEY (id_persona) REFERENCES personas(id)
# );
# Out:
#  * postgresql://postgres:***@localhost:5432/Tarea1DB
# Done.
# []

# %% [markdown]
# ## Código Generador de Datos
#
# Ejecute este código para cargar datos a las tablas creadas.
#
# PD: Si el codigo tira error por "violar la unicidad de las PK" es por una coincidencia de numeros random, solamente volver a ejecutar el codigo

# %%
#Recuerde haber ejecutado todas las celdas anteriores!

# Generador de timestamp aleatorio.
def generate_timestamp_nacimiento():
    year = r.randint(1970,2022)
    month = r.randint(1,12)
    day = r.randint(1,31)
    
    hour = r.randint(0,23)
    minute = r.randint(0,59)
    second = r.randint(0,59)
    
    if month in [4, 6, 9, 11] and day > 30:
        day = 30
        
    if month == 2 and day > 28:
        day = 28
        
    return datetime(year, month, day, hour, minute, second)

def generate_timestamp_trabajo():
    year = r.randint(2019,2022)
    month = r.randint(1,12)
    day = r.randint(1,31)
    
    hour = r.randint(0,23)
    minute = r.randint(0,59)
    second = r.randint(0,59)
    
    if month in [4, 6, 9, 11] and day > 30:
        day = 30
        
    if month == 2 and day > 28:
        day = 28
        
    return datetime(year, month, day, hour, minute, second)

print("Borrando Datos Antiguos...")

# Limpia la base de datos.
connection.commit() # En caso de algun error
query = 'TRUNCATE TABLE "facciones", "trabajos", "personas", "cuentas_bancarias", "persona_pertenece_faccion", "persona_tiene_trabajo" RESTART IDENTITY'
cursor.execute(query)
connection.commit()

print("Generando Datos...")

facciones = [("FEDRA", "La Agencia Federal de Respuesta a Desastres"), ("Luciérnagas", "Grupo de milicias revolucionario"), ("Carroñeros", "Sin identificación"), ("Pythonia", "Grupo defensor de la libertad"), ("MaCdonia", "Los exiliados de la carceles"), ("JavaScriptia", "Grupo defensor de la paz")]
trabajos = [("Limpieza", "Encargado de limpiar las calles"),
("Limpiador de cloacas","Encargado de limpiar las cloacas"),
("Militar","Encargado de proteger la ciudad"),
("Explorador","Encargado de explorar la ciudad"),
("Médico","encargado de curar a los enfermos"),
("Profesor","Encargado de enseñar a los niños"),
("Cremador","Encargado de quemar los cadáveres"),
("Científico","Encargado de investigar"),
("Cocinero","Encargado de cocinar"),
("Carpintero","Encargado de construir"),
("Cerrajero","Encargado de reparar las cerraduras"),
("Cartero","Encargado de repartir los correos"),
("Cajero","Encargado de cobrar los impuestos")]
tipos_de_cuenta_bancaria = ["Cuenta Vista", "Cuenta Ahorro", "Cuenta Corriente", "Cuenta RUT", "Cuenta de Inversion", "Cuenta PrePago", "Cuenta de Credito"]
bancos = ["FedraBank S.A", "Banco Pedrito Pascal SpA", "Banco Pythonia S.A", "Banco de la Nación S.A", "Banco Santander SpA", "Banco BCI SpA", "Banco Estado SpA", "Banco Consorcio S.A", "Banco BBVA", "Banco Scotiabank"]

# Variables.
n_facciones = len(facciones)
n_trabajos = len(trabajos)
n_personas = 1000
n_cuentas_bancarias = 120
n_persona_pertenece_faccion = 300
n_persona_tiene_trabajo = 300
n_casados = 100

# Genera personas.
personas = []
for _ in range(n_personas):
    nombre = names.get_first_name()
    apellidos = names.get_last_name()+" "+names.get_last_name()
    fecha_nacimiento = generate_timestamp_nacimiento()
    infectado = r.choice([True, False])
    
    personas.append((nombre, apellidos, fecha_nacimiento, infectado, None))


# Genera cuentas bancarias.
cuentas_bancarias = []
for _ in range(n_cuentas_bancarias):
    tipo_de_cuenta = r.choice(tipos_de_cuenta_bancaria)
    banco = r.choice(bancos)
    saldo = r.randint(0, 10000)
    id_persona = r.choice(range(1, n_personas+1))
    
    cuentas_bancarias.append((tipo_de_cuenta, banco, saldo, id_persona))
    
    
# Generate persona_pertenece_faccion.
persona_pertenece_faccion = set([(r.choice(range(1, n_personas+1)), r.choice(range(1, n_facciones+1))) for _ in range(1, n_persona_pertenece_faccion+1)])

# Generate persona_tiene_trabajo.
persona_tiene_trabajo_prev = set([(r.choice(range(1, n_personas+1)), r.choice(range(1, n_trabajos+1))) for _ in range(1, n_persona_tiene_trabajo+1)])
persona_tiene_trabajo = [(id_persona, id_trabajo, r.choice([True, False]), generate_timestamp_trabajo()) for id_persona, id_trabajo in persona_tiene_trabajo_prev]
    
# SQL Statements.
inserts = [
    'INSERT INTO "facciones" ("nombre", "descripcion") VALUES (%s, %s);',
    'INSERT INTO "trabajos" ("nombre", "descripcion", "sueldo") VALUES (%s, %s, %s);',
    'INSERT INTO "personas" ("nombre", "apellidos", "fecha_nacimiento", "infectado", "conyugue") VALUES (%s, %s, %s, %s, %s);',
    'INSERT INTO "cuentas_bancarias" ("tipo_de_cuenta", "banco", "saldo", "id_persona") VALUES (%s, %s, %s, %s);',
    'INSERT INTO "persona_pertenece_faccion" ("id_persona", "id_faccion") VALUES (%s, %s);',
    'INSERT INTO "persona_tiene_trabajo" ("id_persona", "id_trabajo", "estado", "ultima_vez_realizado") VALUES (%s, %s, %s, %s);'
]

for faccion in facciones:
    cursor.execute(inserts[0], faccion)

for trabajo in trabajos:
    t = (trabajo[0], trabajo[1], r.randint(100, 5000))
    cursor.execute(inserts[1], t)

# Crear una lista con personas casadas y otra con personas solteras. donde se cambie la ide de la persona que se casó.

for persona in personas:
    cursor.execute(inserts[2], persona)
    
for cb in cuentas_bancarias:
    cursor.execute(inserts[3], cb)

for ppf in persona_pertenece_faccion:
    cursor.execute(inserts[4], ppf)
    
for ptt in persona_tiene_trabajo:
    cursor.execute(inserts[5], ptt)
    
connection.commit()


# Generar Matrimonios
n_repetidos = []

for i in range(n_casados):
    random = r.randint(1, n_personas)
    if random in n_repetidos:
        continue
    else:
        random2 = r.randint(1, n_personas)
        if random2 in n_repetidos:
            continue
        else:
            n_repetidos.append(random)
            n_repetidos.append(random2)
            cursor.execute("UPDATE personas SET conyugue = %s WHERE id = %s", (random2, random))
            cursor.execute("UPDATE personas SET conyugue = %s WHERE id = %s", (random, random2))
            connection.commit()

print("Todo Listo!")
# Out:
# Borrando Datos Antiguos...
# Generando Datos...
# Todo Listo!

# %% [markdown]
# ## Consultas (64 pts.)
#
# Escriba aquí las consultas pedidas. Recuerde agregar una descripción _breve_ de cómo funciona la solución. **Escriba las consultas de forma ordenada.**
#
# **NOTA:** Cuando en una consulta diga "X cosa" significa que ustedes deben de elegir ese X por lo que para cualquier otro X debe de funcionar de igual forma.

# %% [markdown]
# ### Consulta 1 (6 pts)
# **ID, nombre y primer apellido de los habitantes de FEDRA**
#
# Ejemplo:
#
# |ID |  Nombre      |  Apellido  |
# |---|-----------|-----------|
# | 12 |Joel | Miller |
# |21 | Ellie | Williams |
# | ... | ... | ... |
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
#
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */
#
# SELECT
#     *
# FROM
#     personas;
# Out:
#  * postgresql://postgres:***@localhost:5432/Tarea1DB
# 1000 rows affected.
# [(1, 'Stephen', 'Massey Free', datetime.date(1982, 3, 2), False, None),
#  (2, 'Donn', 'Rutenberg Mcknight', datetime.date(1996, 6, 4), False, None),
#  (5, 'Richard', 'Rivera Ciprian', datetime.date(1997, 10, 6), False, None),
#  (6, 'Charlene', 'Wysocki Thomas', datetime.date(1986, 2, 14), False, None),
#  (7, 'Bernice', 'Waddle Ammons', datetime.date(1993, 12, 16), True, None),
#  (8, 'Vernon', 'Cliff Capito', datetime.date(1986, 11, 24), True, None),
#  (9, 'Bruce', 'Heywood Parker', datetime.date(2012, 4, 18), True, None),
#  (10, 'Patty', 'Johnson Garbacz', datetime.date(2016, 8, 7), True, None),
#  (11, 'Patrick', 'Hill Guillory', datetime.date(2015, 2, 16), False, None),
#  (12, 'Teresita', 'Eatman Robison', datetime.date(1979, 2, 23), True, None),
#  (13, 'Terry', 'Gonzales Switzer', datetime.date(1993, 10, 25), False, None),
#  (14, 'Jay', 'Davis Reed', datetime.date(2012, 9, 24), False, None),
#  (15, 'Abigail', 'Howell Wilson', datetime.date(2003, 8, 22), True, None),
#  (16, 'Dee', 'Ascolese Isaksen', datetime.date(2008, 5, 17), False, None),
#  (18, 'Burl', 'Homer Griffin', datetime.date(1977, 8, 30), True, None),
#  (19, 'Jessica', 'Gomez Dreher', datetime.date(1976, 6, 20), True, None),
#  (20, 'Megan', 'Bennett Stringfellow', datetime.date(2016, 6, 7), True, None),
#  (21, 'Margarita', 'Thompson Ferguson', datetime.date(2008, 1, 25), True, None),
#  (22, 'Celeste', 'Benson Yates', datetime.date(2000, 6, 16), True, None),
#  (24, 'Marvin', 'Rockwell Smith', datetime.date(1972, 8, 21), False, None),
#  (26, 'Gary', 'Humes Bryant', datetime.date(1975, 9, 23), False, None),
#  (27, 'Irene', 'Bullock Nase', datetime.date(2010, 3, 30), False, None),
#  (28, 'Ashley', 'Hancock Khoury', datetime.date(1995, 4, 14), False, None),
#  (29, 'Herb', 'Morgan Jones', datetime.date(1973, 12, 26), False, None),
#  (30, 'Karl', 'Curb Hernandez', datetime.date(1986, 6, 30), False, None),
#  (31, 'Gerald', 'Bartz Hutchison', datetime.date(1980, 8, 29), False, None),
#  (33, 'Marian', 'Guardado Justice', datetime.date(2010, 7, 20), True, None),
#  (34, 'Ana', 'Stannard Harrison', datetime.date(2007, 10, 30), False, None),
#  (36, 'Mathew', 'Dake Chase', datetime.date(1975, 8, 10), True, None),
#  (37, 'Matthew', 'Smith Marshall', datetime.date(1978, 5, 26), False, None),
#  (38, 'Kenneth', 'Cooper Thomas', datetime.date(1982, 12, 23), True, None),
#  (39, 'Roger', 'Panto Feather', datetime.date(1979, 3, 8), False, None),
#  (40, 'Selena', 'Negron Orwig', datetime.date(1999, 12, 12), False, None),
#  (41, 'Jennifer', 'Schwartz Debar', datetime.date(2013, 6, 10), False, None),
#  (42, 'Michael', 'Humphrey Chapman', datetime.date(2016, 9, 8), True, None),
#  (44, 'Barbara', 'Allbright Poole', datetime.date(2015, 12, 9), True, None),
#  (45, 'Mary', 'Peak Loiseau', datetime.date(1974, 8, 31), False, None),
#  (47, 'Willie', 'Law Nyman', datetime.date(2012, 9, 25), False, None),
#  (48, 'Patricia', 'Reid Ward', datetime.date(1975, 6, 1), True, None),
#  (49, 'William', 'Davis Chisley', datetime.date(1993, 5, 3), False, None),
#  (50, 'Jan', 'Armstrong Deloach', datetime.date(2022, 10, 1), True, None),
#  (52, 'Jessie', 'Jones Garcia', datetime.date(1983, 10, 27), True, None),
#  (53, 'Melvin', 'Barbee Pearson', datetime.date(1979, 5, 1), True, None),
#  (54, 'Albert', 'King Bowlds', datetime.date(1985, 7, 7), True, None),
#  (55, 'Rose', 'Robles Shanholtzer', datetime.date(1981, 12, 30), False, None),
#  (56, 'Bruce', 'Reed Smith', datetime.date(2022, 12, 23), True, None),
#  (57, 'Maren', 'May Mitchell', datetime.date(2015, 3, 30), True, None),
#  (58, 'Francis', 'Mcleod Valdez', datetime.date(1978, 4, 30), True, None),
#  (59, 'Brenda', 'Mehtani Kort', datetime.date(2022, 5, 15), False, None),
#  (60, 'Lilia', 'Burkhart Uplinger', datetime.date(1997, 7, 11), False, None),
#  (62, 'Stephanie', 'Evans Garnett', datetime.date(1975, 10, 28), False, None),
#  (63, 'David', 'Griffin Neu', datetime.date(2017, 9, 30), False, None),
#  (64, 'Lana', 'Kelly Pearson', datetime.date(2022, 3, 27), True, None),
#  (65, 'Sandra', 'Strawn Hill', datetime.date(1997, 11, 20), False, None),
#  (66, 'Sally', 'Lewis Helstrom', datetime.date(1993, 11, 27), True, None),
#  (67, 'Bridget', 'Jones Clopton', datetime.date(2000, 4, 23), True, None),
#  (69, 'Muriel', 'Newman Cannon', datetime.date(2020, 7, 5), True, None),
#  (70, 'Daren', 'Loque Fisher', datetime.date(1998, 8, 10), False, None),
#  (73, 'Antonio', 'Serasio Patrick', datetime.date(2011, 12, 9), False, None),
#  (74, 'Emily', 'Scala Clynes', datetime.date(1993, 7, 31), True, None),
#  (75, 'Luis', 'Way Sparks', datetime.date(2010, 2, 4), False, None),
#  (76, 'Sherri', 'Gundrum Knight', datetime.date(1993, 12, 9), True, None),
#  (77, 'Eugene', 'Harvey Alcorn', datetime.date(1990, 3, 15), True, None),
#  (78, 'Louis', 'Easterly Dean', datetime.date(2013, 3, 15), True, None),
#  (79, 'Charles', 'Wingfield Cole', datetime.date(2002, 3, 17), True, None),
#  (80, 'Holly', 'Stewart Novetsky', datetime.date(2009, 11, 27), False, None),
#  (82, 'Rita', 'Griffin Whitehead', datetime.date(2009, 6, 20), True, None),
#  (83, 'Julian', 'Yazzie Blount', datetime.date(1980, 10, 31), False, None),
#  (85, 'Maria', 'Foglesong Buchanon', datetime.date(1989, 2, 19), False, None),
#  (87, 'Dan', 'Oneill Connolly', datetime.date(2017, 6, 30), True, None),
#  (88, 'Rebecca', 'Helfer Costa', datetime.date(1981, 11, 12), True, None),
#  (89, 'Kelly', 'Mcbride Turner', datetime.date(1970, 5, 28), False, None),
#  (90, 'George', 'Noel Sollenberger', datetime.date(2007, 8, 28), False, None),
#  (91, 'Charles', 'Derr Mendoza', datetime.date(1980, 11, 3), False, None),
#  (93, 'Harry', 'Denmon Bragg', datetime.date(1983, 3, 27), False, None),
#  (94, 'Andrew', 'Grimes Matthewson', datetime.date(1983, 11, 16), True, None),
#  (95, 'Madeline', 'Rubio Vaught', datetime.date(2015, 12, 22), False, None),
#  (96, 'Carl', 'Johnson Wall', datetime.date(2008, 4, 27), True, None),
#  (97, 'John', 'Bond Morris', datetime.date(2016, 8, 26), True, None),
#  (98, 'Jim', 'Zamora Weir', datetime.date(1997, 12, 16), False, None),
#  (100, 'Alice', 'Brown Burg', datetime.date(2019, 9, 3), True, None),
#  (101, 'Vanessa', 'Wilks Cromer', datetime.date(2003, 9, 25), True, None),
#  (102, 'Kay', 'Smith Rhoades', datetime.date(1985, 9, 4), True, None),
#  (103, 'Thomas', 'Threet Pineau', datetime.date(2010, 8, 18), True, None),
#  (104, 'Aaron', 'Ward Lopez', datetime.date(1982, 1, 18), True, None),
#  (105, 'Shannon', 'Schumacher Johnson', datetime.date(2018, 8, 3), False, None),
#  (107, 'Cleo', 'Ellis Malloy', datetime.date(1996, 7, 21), False, None),
#  (108, 'Guadalupe', 'Hanford Ligon', datetime.date(2022, 4, 27), False, None),
#  (110, 'Jennifer', 'Thompson Colvin', datetime.date(1989, 11, 23), True, None),
#  (111, 'John', 'Turpen Urban', datetime.date(1985, 10, 23), True, None),
#  (112, 'Juanita', 'Fernandez Ziegler', datetime.date(2017, 4, 13), True, None),
#  (113, 'John', 'Lamotte Truiolo', datetime.date(2004, 12, 30), True, None),
#  (114, 'Gerald', 'Dorn Hurst', datetime.date(2016, 6, 22), False, None),
#  (115, 'Sylvia', 'Rados Ashburn', datetime.date(2022, 9, 16), True, None),
#  (116, 'Erica', 'Pershall Scott', datetime.date(1999, 10, 13), True, None),
#  (117, 'Julia', 'Routt Smith', datetime.date(1982, 6, 16), False, None),
#  (118, 'Clarence', 'Quinn Mcqueen', datetime.date(1988, 2, 6), False, None),
#  (119, 'James', 'Hill Fields', datetime.date(1979, 12, 13), False, None),
#  (122, 'Earl', 'Oquendo Sisler', datetime.date(2006, 7, 15), True, None),
#  (123, 'Ida', 'Mallory Short', datetime.date(2008, 1, 6), False, None),
#  (124, 'Darron', 'Roszel Siefert', datetime.date(1992, 8, 1), False, None),
#  (125, 'Jeanne', 'Ikeda Santoro', datetime.date(1977, 4, 25), False, None),
#  (126, 'Stephen', 'Bartley Greaves', datetime.date(1993, 8, 29), True, None),
#  (51, 'Imogene', 'Moyer Paxton', datetime.date(2001, 12, 8), True, 240),
#  (32, 'Aurora', 'Lynch Uhrig', datetime.date(2007, 4, 7), False, 340),
#  (68, 'Sharon', 'Wright Majure', datetime.date(2013, 10, 29), False, 969),
#  (121, 'Judy', 'Kurtz Ginn', datetime.date(2015, 4, 28), True, 223),
#  (106, 'John', 'Walker Wheeler', datetime.date(1993, 10, 17), False, 501),
#  (35, 'Steven', 'Irby Hamernik', datetime.date(1994, 10, 14), True, 3),
#  (61, 'Francis', 'Pratt Delapena', datetime.date(2009, 7, 4), True, 993),
#  (71, 'Clarence', 'Hirsch Hubbard', datetime.date(2012, 8, 9), False, 504),
#  (72, 'Ryan', 'Lopez Sechrist', datetime.date(2001, 1, 18), False, 698),
#  (17, 'Karen', 'Harrington Walker', datetime.date(2001, 7, 17), True, 887),
#  (4, 'Lily', 'Bowen Ringel', datetime.date(2022, 9, 18), False, 86),
#  (92, 'Vance', 'Parsons Fleming', datetime.date(1987, 6, 19), True, 333),
#  (81, 'Ruth', 'Carrigan Bottorff', datetime.date(1971, 2, 26), False, 185),
#  (46, 'William', 'Martinez Day', datetime.date(1978, 10, 2), True, 299),
#  (109, 'Raul', 'Allen Green', datetime.date(2016, 2, 1), True, 765),
#  (43, 'Kimberly', 'Luckett Jackson', datetime.date(2002, 9, 1), True, 905),
#  (99, 'Gilbert', 'Mcgwin Robinson', datetime.date(1989, 12, 28), True, 395),
#  (84, 'John', 'Boggs Santiago', datetime.date(1975, 7, 7), False, 453),
#  (120, 'Aaron', 'Robleto Chase', datetime.date(2020, 6, 10), False, 198),
#  (128, 'Sarah', 'Stollsteimer Ford', datetime.date(1994, 7, 10), False, None),
#  (129, 'Ronald', 'Leonard Mcknight', datetime.date(1997, 9, 15), True, None),
#  (131, 'Alfred', 'Hinton Lee', datetime.date(2009, 5, 15), True, None),
#  (132, 'John', 'Fitzgerald Phillips', datetime.date(1993, 2, 27), True, None),
#  (133, 'Arica', 'Mierzejewski Mathis', datetime.date(2009, 4, 11), False, None),
#  (134, 'Claudine', 'Taylor Brown', datetime.date(2018, 2, 11), False, None),
#  (135, 'Mary', 'Pence Singleton', datetime.date(2003, 8, 15), True, None),
#  (136, 'Paula', 'Mikulak Sak', datetime.date(2002, 9, 2), True, None),
#  (137, 'Marie', 'Mcallen Jansen', datetime.date(2015, 2, 11), False, None),
#  (138, 'Hyon', 'Quirion Welch', datetime.date(1989, 2, 17), False, None),
#  (140, 'Etta', 'Kirk Ott', datetime.date(2013, 5, 13), True, None),
#  (141, 'Tommy', 'Kane Verde', datetime.date(2008, 9, 13), True, None),
#  (145, 'Katharina', 'Abell Neighbors', datetime.date(1973, 10, 19), True, None),
#  (146, 'Louis', 'Sizemore Dejesus', datetime.date(2019, 10, 13), True, None),
#  (147, 'Jeanette', 'Leich Highshaw', datetime.date(2021, 12, 21), False, None),
#  (148, 'Donna', 'Buford Williams', datetime.date(1972, 10, 16), False, None),
#  (149, 'Austin', 'Bookman Allen', datetime.date(2017, 2, 24), True, None),
#  (151, 'Cathy', 'Long Toler', datetime.date(1993, 9, 10), True, None),
#  (152, 'Enrique', 'Johnson Bailey', datetime.date(2001, 3, 9), True, None),
#  (154, 'Carolyn', 'Riddle Smith', datetime.date(1972, 9, 12), False, None),
#  (155, 'Lenore', 'Clark Truman', datetime.date(1982, 3, 10), True, None),
#  (157, 'Emily', 'Taylor Nichols', datetime.date(2018, 12, 25), False, None),
#  (158, 'Kristina', 'Cassidy Ferrell', datetime.date(2008, 9, 22), True, None),
#  (159, 'Wayne', 'Meagher Tedesco', datetime.date(2000, 3, 20), False, None),
#  (160, 'Morris', 'Borrell Sturgis', datetime.date(1973, 8, 10), True, None),
#  (161, 'Robert', 'Rodriguez Cleveland', datetime.date(2007, 8, 15), False, None),
#  (162, 'William', 'Bailey Krick', datetime.date(1984, 7, 6), False, None),
#  (163, 'Jerry', 'Shepherd Purdom', datetime.date(2016, 11, 15), False, None),
#  (164, 'Kelly', 'Gamache Nohel', datetime.date(2022, 11, 2), False, None),
#  (165, 'Mary', 'Hershman Simmons', datetime.date(1994, 2, 19), True, None),
#  (166, 'Molly', 'Messick Johnson', datetime.date(2006, 11, 24), False, None),
#  (167, 'Charles', 'Culliton Dorsey', datetime.date(1972, 2, 13), False, None),
#  (169, 'Joseph', 'Kio Furman', datetime.date(2000, 6, 19), False, None),
#  (170, 'Leslie', 'Cassell Bryant', datetime.date(1997, 10, 8), True, None),
#  (171, 'Kathy', 'Gilliam Roe', datetime.date(2013, 1, 19), True, None),
#  (172, 'Sarah', 'Rodriguez Ling', datetime.date(2004, 10, 24), True, None),
#  (173, 'Jane', 'Leblanc Holder', datetime.date(1998, 1, 8), True, None),
#  (174, 'Jordan', 'Styer Schreiner', datetime.date(1996, 9, 26), True, None),
#  (175, 'Ronald', 'Nale Keough', datetime.date(2009, 9, 30), False, None),
#  (176, 'Juanita', 'Olson Villareal', datetime.date(2021, 4, 12), False, None),
#  (177, 'James', 'Withers Stpierre', datetime.date(2007, 7, 6), False, None),
#  (178, 'Edgar', 'Fitzgerald Lynch', datetime.date(1984, 3, 1), False, None),
#  (179, 'Paul', 'Dickey Kemppainen', datetime.date(1975, 12, 10), True, None),
#  (180, 'Sabrina', 'Pritts Hammett', datetime.date(2015, 7, 1), True, None),
#  (186, 'Steven', 'Lott Johnson', datetime.date(2015, 1, 9), False, None),
#  (187, 'Elmer', 'Topping Swindell', datetime.date(2010, 5, 28), True, None),
#  (188, 'James', 'Roberts Proffitt', datetime.date(2011, 1, 14), False, None),
#  (190, 'Gary', 'Solis Smith', datetime.date(2001, 11, 8), False, None),
#  (191, 'Gregory', 'Greer Bailey', datetime.date(1992, 3, 14), False, None),
#  (192, 'Genevieve', 'Hutchins Armstead', datetime.date(1988, 12, 23), True, None),
#  (193, 'Cecil', 'Barrier Gonzalez', datetime.date(1970, 9, 30), False, None),
#  (194, 'Morris', 'Botts Priddy', datetime.date(1982, 7, 25), False, None),
#  (195, 'David', 'Burchette Weaver', datetime.date(1977, 1, 11), True, None),
#  (196, 'Sammie', 'Stetson Partain', datetime.date(2014, 3, 6), False, None),
#  (197, 'John', 'Strassel Reiss', datetime.date(2019, 2, 21), True, None),
#  (199, 'Michell', 'Jackson Sanchez', datetime.date(1998, 12, 18), True, None),
#  (200, 'Carolyn', 'Denison Brown', datetime.date(1997, 2, 28), True, None),
#  (201, 'John', 'Hooker Sellers', datetime.date(2004, 6, 12), True, None),
#  (202, 'Jeff', 'Taylor Trombetta', datetime.date(2020, 2, 7), True, None),
#  (203, 'Scott', 'Rodriguez Shockey', datetime.date(1991, 11, 9), False, None),
#  (204, 'James', 'Kiley Cruz', datetime.date(1990, 6, 9), False, None),
#  (205, 'Cynthia', 'Lee Harper', datetime.date(1979, 5, 7), True, None),
#  (206, 'Linda', 'Nguyen Mcghee', datetime.date(2006, 2, 27), False, None),
#  (207, 'Ora', 'Barela Handley', datetime.date(1998, 6, 24), False, None),
#  (209, 'Kimberly', 'Esquilin Elio', datetime.date(2013, 10, 25), True, None),
#  (210, 'Martha', 'Beaudoin Johnson', datetime.date(2018, 1, 11), False, None),
#  (211, 'Michael', 'Townsend Ivey', datetime.date(1999, 9, 17), True, None),
#  (212, 'Velma', 'Garcia Drake', datetime.date(1976, 7, 1), False, None),
#  (213, 'Pedro', 'Delgado Tinajero', datetime.date(2010, 1, 25), True, None),
#  (214, 'Francine', 'Carter Miller', datetime.date(1983, 10, 23), True, None),
#  (215, 'Johnnie', 'Begley Fields', datetime.date(1979, 7, 13), True, None),
#  (216, 'Edith', 'Keating Brookhouse', datetime.date(1995, 2, 28), True, None),
#  (217, 'Irene', 'Jenness Heminger', datetime.date(1996, 11, 1), True, None),
#  (218, 'Daniel', 'Whitehead Kane', datetime.date(2005, 11, 5), False, None),
#  (219, 'Linda', 'Johnson Kazmierczak', datetime.date(1998, 5, 1), False, None),
#  (220, 'Travis', 'Rock Furth', datetime.date(1974, 8, 18), False, None),
#  (221, 'Leona', 'Howell Brown', datetime.date(2005, 8, 30), False, None),
#  (222, 'Michele', 'Sitter Bullock', datetime.date(2020, 6, 26), True, None),
#  (224, 'Jimmie', 'Baker Mondesir', datetime.date(2000, 3, 21), True, None),
#  (225, 'Robert', 'Rue Esbenshade', datetime.date(1978, 11, 4), False, None),
#  (226, 'May', 'Butler Henson', datetime.date(2014, 1, 1), False, None),
#  (227, 'John', 'Williams Hambric', datetime.date(1981, 5, 13), True, None),
#  (228, 'Ryan', 'Stevens Rich', datetime.date(2018, 12, 18), True, None),
#  (229, 'Ryan', 'Ehmann Vanaman', datetime.date(1991, 9, 30), False, None),
#  (230, 'Nathan', 'Kennedy Ramirez', datetime.date(1992, 8, 2), True, None),
#  (231, 'Melissa', 'Perry Miller', datetime.date(1971, 9, 5), True, None),
#  (232, 'Mary', 'Han Putnam', datetime.date(1973, 8, 6), False, None),
#  (233, 'Arielle', 'Golding Arndt', datetime.date(2008, 1, 17), False, None),
#  (234, 'Martha', 'Price Howard', datetime.date(2022, 4, 27), True, None),
#  (235, 'Karen', 'Cooper Hawkins', datetime.date(2006, 11, 1), False, None),
#  (236, 'David', 'Bowen Marion', datetime.date(1989, 3, 7), True, None),
#  (237, 'James', 'Ourada Glass', datetime.date(1996, 2, 28), False, None),
#  (238, 'Nikia', 'Gibbs Bosley', datetime.date(1993, 11, 22), False, None),
#  (239, 'Mildred', 'Cuellar Neal', datetime.date(2001, 7, 12), True, None),
#  (241, 'Kathleen', 'Blandon Lapoint', datetime.date(1981, 3, 3), True, None),
#  (243, 'Elizabeth', 'Jacobsen Warner', datetime.date(1990, 8, 9), True, None),
#  (244, 'Barbara', 'Johnson Smith', datetime.date(1976, 5, 12), True, None),
#  (245, 'Linda', 'Farris Beal', datetime.date(1977, 11, 5), False, None),
#  (246, 'Cory', 'House Vogt', datetime.date(2018, 10, 5), True, None),
#  (247, 'Glenda', 'Dickerson Rodriguez', datetime.date(2012, 6, 23), True, None),
#  (248, 'Stephen', 'Lynch York', datetime.date(2004, 1, 1), True, None),
#  (249, 'Ricky', 'Newman Biddix', datetime.date(2006, 6, 4), True, None),
#  (250, 'Lucille', 'Douglas Duckey', datetime.date(1997, 4, 22), True, None),
#  (251, 'Deborah', 'Jackson Bridges', datetime.date(1973, 10, 3), False, None),
#  (156, 'James', 'Ward Butler', datetime.date(2001, 3, 30), False, 704),
#  (150, 'Al', 'Lusk Ponder', datetime.date(2015, 5, 17), False, 449),
#  (153, 'Ralph', 'Blanding Klein', datetime.date(2016, 3, 24), True, 874),
#  (223, 'Robert', 'Black Walling', datetime.date(2008, 10, 27), False, 121),
#  (139, 'Cynthia', 'Norwood Gonzalez', datetime.date(2015, 10, 16), False, 726),
#  (127, 'Elizabeth', 'Taube Benitez', datetime.date(1974, 2, 28), False, 602),
#  (143, 'Steven', 'Bowman White', datetime.date(1982, 11, 5), True, 945),
#  (168, 'Betty', 'Flurry Riley', datetime.date(1973, 3, 21), True, 851),
#  (185, 'Cynthia', 'Vanbuskirk Suriel', datetime.date(1974, 11, 14), False, 81),
#  (184, 'Frederick', 'Pimental Dowd', datetime.date(1984, 9, 3), True, 927),
#  (183, 'Elijah', 'Little Boyd', datetime.date(1988, 2, 18), True, 242),
#  (130, 'Pat', 'Potts Ladd', datetime.date(1985, 2, 28), True, 321),
#  (181, 'Mackenzie', 'Bienenstock Taft', datetime.date(1979, 1, 15), False, 279),
#  (208, 'Blanca', 'Melanson Bonner', datetime.date(2022, 6, 30), True, 424),
#  (144, 'Peter', 'Lopez Downes', datetime.date(2000, 8, 20), True, 423),
#  (182, 'James', 'Mcgovern Sykes', datetime.date(2000, 2, 7), False, 870),
#  (198, 'Andrew', 'Orbin Vines', datetime.date(2003, 10, 9), False, 120),
#  (142, 'Larry', 'Federico Johnston', datetime.date(2001, 5, 9), False, 928),
#  (254, 'Linda', 'Rawls Jones', datetime.date(1996, 9, 14), False, None),
#  (255, 'Daniel', 'Adams Hubbard', datetime.date(2011, 4, 16), False, None),
#  (256, 'Matthew', 'Vinion Rosenfeld', datetime.date(1986, 10, 14), False, None),
#  (257, 'Vera', 'Crum Whiteside', datetime.date(2018, 9, 10), True, None),
#  (258, 'Ivan', 'Alford Estes', datetime.date(1980, 11, 28), False, None),
#  (259, 'Christopher', 'Ramirez Pulis', datetime.date(2018, 2, 16), True, None),
#  (260, 'Edward', 'Greenwood Bertozzi', datetime.date(2006, 4, 4), False, None),
#  (261, 'Andrew', 'Charles Powell', datetime.date(1972, 3, 5), False, None),
#  (262, 'Gertrude', 'Morris Guzman', datetime.date(2012, 11, 29), False, None),
#  (263, 'Kenneth', 'Perrin Church', datetime.date(1970, 10, 10), True, None),
#  (264, 'Salena', 'Ratterman Fisk', datetime.date(2020, 2, 1), False, None),
#  (265, 'Peggy', 'Dobkins Henning', datetime.date(1974, 12, 19), False, None),
#  (267, 'Viola', 'Merrow Kenny', datetime.date(1980, 2, 13), False, None),
#  (269, 'Lisa', 'Ramos Levay', datetime.date(1985, 8, 31), False, None),
#  (270, 'Gail', 'Topp Ikehara', datetime.date(2009, 8, 15), False, None),
#  (272, 'Melissa', 'Martin Smith', datetime.date(2007, 12, 20), True, None),
#  (273, 'Joaquin', 'Jones Fogle', datetime.date(1981, 11, 30), False, None),
#  (274, 'Arthur', 'Mace Spatz', datetime.date(2010, 8, 10), False, None),
#  (275, 'Annette', 'Weaver Milton', datetime.date(1985, 5, 3), False, None),
#  (276, 'Ronald', 'Chavez Henley', datetime.date(2010, 7, 3), False, None),
#  (277, 'Sherry', 'Bardwell Bunting', datetime.date(1990, 10, 31), False, None),
#  (278, 'Ruth', 'Eastman Cross', datetime.date(2015, 3, 18), True, None),
#  (280, 'Charles', 'Morris Morrison', datetime.date(1972, 2, 19), True, None),
#  (281, 'Katherine', 'Nevin Rose', datetime.date(2015, 9, 1), True, None),
#  (282, 'Diane', 'Carter Brockman', datetime.date(1995, 8, 22), False, None),
#  (283, 'Marshall', 'Collins Almendarez', datetime.date(2005, 11, 13), False, None),
#  (284, 'Michele', 'Cota Seibel', datetime.date(1976, 11, 29), False, None),
#  (285, 'Andrea', 'Andrews Rogers', datetime.date(1996, 8, 6), True, None),
#  (286, 'Pedro', 'Donahue Alvarez', datetime.date(2022, 5, 6), False, None),
#  (287, 'David', 'Gearhart Luna', datetime.date(2019, 6, 23), False, None),
#  (288, 'Hilary', 'Miller Ellman', datetime.date(2016, 9, 8), False, None),
#  (289, 'Terry', 'Everett Alvarado', datetime.date(1979, 12, 18), False, None),
#  (290, 'Michelle', 'Barth Douds', datetime.date(1970, 1, 17), True, None),
#  (291, 'Julie', 'Pipkins Fisher', datetime.date(2002, 3, 5), False, None),
#  (292, 'Troy', 'Wilson Altman', datetime.date(1990, 1, 18), False, None),
#  (293, 'Ryan', 'Maier King', datetime.date(1990, 6, 12), True, None),
#  (294, 'Marcus', 'Calcote Willis', datetime.date(1976, 12, 27), False, None),
#  (295, 'Debra', 'Alexander Scott', datetime.date(1991, 9, 11), True, None),
#  (296, 'Kim', 'Jones Smith', datetime.date(1995, 4, 19), True, None),
#  (297, 'Suzanne', 'Romansky Roblez', datetime.date(1990, 7, 6), False, None),
#  (298, 'Matthew', 'Dowdell Eatmon', datetime.date(2015, 3, 3), False, None),
#  (300, 'Dane', 'Smith Mcdermott', datetime.date(1990, 7, 16), False, None),
#  (301, 'Muriel', 'Cook Mccleskey', datetime.date(2017, 9, 14), False, None),
#  (302, 'Jill', 'Strefeler Coffman', datetime.date(2011, 3, 17), False, None),
#  (303, 'Amy', 'Laxson Chavira', datetime.date(1982, 3, 25), True, None),
#  (304, 'James', 'Brown Ortiz', datetime.date(1992, 8, 29), False, None),
#  (305, 'James', 'Matthews Shafer', datetime.date(2012, 1, 9), False, None),
#  (306, 'Robert', 'Alford Pach', datetime.date(1976, 9, 12), True, None),
#  (307, 'Samantha', 'Pahulu Russell', datetime.date(2016, 9, 9), True, None),
#  (308, 'Maurice', 'Faulk Sanchez', datetime.date(1993, 6, 14), True, None),
#  (310, 'Jose', 'Ordman Salem', datetime.date(1995, 12, 3), True, None),
#  (311, 'Dorothy', 'Lowder Maurer', datetime.date(2001, 9, 2), False, None),
#  (312, 'Peter', 'Guerra Jefferson', datetime.date(1973, 7, 25), False, None),
#  (313, 'Kenneth', 'Vanderpool Harrison', datetime.date(1970, 9, 13), False, None),
#  (314, 'Lucille', 'Holland Williams', datetime.date(1990, 1, 26), False, None),
#  (315, 'Christine', 'Taylor Lowe', datetime.date(1977, 8, 16), False, None),
#  (316, 'Lillian', 'Nabb Gariepy', datetime.date(2007, 7, 4), False, None),
#  (317, 'Joseph', 'Washington Washington', datetime.date(1974, 11, 10), False, None),
#  (318, 'Charles', 'Campos Cassidy', datetime.date(1988, 10, 28), True, None),
#  (319, 'Rosalyn', 'Brymer Hesselschward', datetime.date(1977, 12, 24), False, None),
#  (320, 'Paul', 'Runge Dunbar', datetime.date(2012, 8, 1), True, None),
#  (322, 'Paul', 'Avera Ellis', datetime.date(2018, 3, 17), True, None),
#  (323, 'Fred', 'Knight Stout', datetime.date(1997, 7, 21), True, None),
#  (324, 'Esther', 'Boyce Gagnon', datetime.date(1997, 10, 17), True, None),
#  (325, 'Jimmy', 'Miller Herzog', datetime.date(1976, 7, 6), True, None),
#  (326, 'Windy', 'Christensen Bassett', datetime.date(1984, 2, 2), True, None),
#  (327, 'Wm', 'Alexander Surrett', datetime.date(1975, 12, 22), True, None),
#  (328, 'Joe', 'Meredith Timme', datetime.date(1996, 2, 5), False, None),
#  (329, 'Maria', 'Brobst Klein', datetime.date(2002, 11, 1), True, None),
#  (330, 'John', 'Legault Merritt', datetime.date(1979, 7, 22), True, None),
#  (331, 'Jonathan', 'Lopez Boettcher', datetime.date(1975, 3, 21), False, None),
#  (332, 'Lisa', 'Depaul Statum', datetime.date(1976, 4, 12), True, None),
#  (334, 'Robert', 'Brown Berry', datetime.date(1987, 9, 5), True, None),
#  (335, 'Bonnie', 'Foley Hammers', datetime.date(1993, 9, 24), True, None),
#  (336, 'Steven', 'Yoder Brunell', datetime.date(2001, 4, 7), True, None),
#  (337, 'Felisa', 'Johnson Johnson', datetime.date(2010, 10, 21), False, None),
#  (338, 'Jeffrey', 'Larochelle Robles', datetime.date(1976, 11, 13), False, None),
#  (339, 'Anne', 'Kubica Arevalo', datetime.date(2019, 5, 20), True, None),
#  (341, 'Mary', 'Alexander Propst', datetime.date(1993, 11, 23), False, None),
#  (342, 'Regina', 'Eide Crown', datetime.date(2013, 3, 20), True, None),
#  (343, 'Tammi', 'Wohlrab Cox', datetime.date(1979, 4, 26), True, None),
#  (344, 'Tammy', 'Flores Regalado', datetime.date(1978, 5, 6), True, None),
#  (346, 'Peter', 'Schimke Eads', datetime.date(1982, 7, 28), False, None),
#  (347, 'Salvador', 'Dukes Wright', datetime.date(1986, 1, 25), False, None),
#  (348, 'Terrence', 'Applewhite Ferrell', datetime.date(2007, 1, 29), True, None),
#  (349, 'John', 'Flink Christain', datetime.date(1975, 10, 14), False, None),
#  (350, 'Howard', 'Boyer Denny', datetime.date(2001, 5, 31), True, None),
#  (352, 'Ruby', 'Jones Smith', datetime.date(1983, 6, 9), True, None),
#  (353, 'Robert', 'Kunde Alexander', datetime.date(1993, 6, 21), True, None),
#  (354, 'Barbara', 'Olson Simmering', datetime.date(1990, 2, 6), True, None),
#  (355, 'Mary', 'Gregg Van', datetime.date(2003, 12, 17), True, None),
#  (356, 'Chris', 'Brandon Lipscomb', datetime.date(1992, 10, 16), True, None),
#  (357, 'Petra', 'Francois Degroot', datetime.date(1989, 12, 11), True, None),
#  (358, 'Betty', 'Miller Williams', datetime.date(2007, 11, 16), False, None),
#  (359, 'John', 'Reyes Diego', datetime.date(2012, 8, 14), False, None),
#  (360, 'Timothy', 'Sanderfer Mcclendon', datetime.date(1987, 5, 13), False, None),
#  (361, 'Steven', 'Bailey Hooten', datetime.date(1997, 11, 7), False, None),
#  (362, 'Ethel', 'Edwards Hassler', datetime.date(1989, 6, 20), False, None),
#  (363, 'Elizabeth', 'Kay Foster', datetime.date(1988, 4, 3), True, None),
#  (364, 'Liza', 'Register Downes', datetime.date(2017, 7, 30), True, None),
#  (365, 'Mark', 'Stapler Selvage', datetime.date(1986, 8, 8), True, None),
#  (366, 'James', 'Camarillo Nichols', datetime.date(1975, 8, 13), True, None),
#  (367, 'James', 'Petitjean Sanderson', datetime.date(1993, 12, 18), True, None),
#  (368, 'Jenifer', 'Buchanan Orzechowski', datetime.date(2002, 4, 23), False, None),
#  (369, 'Robert', 'White Aymond', datetime.date(2017, 1, 7), False, None),
#  (370, 'Elba', 'Fujisawa Hill', datetime.date(1978, 3, 28), True, None),
#  (371, 'Kelly', 'Battle Ragan', datetime.date(1972, 11, 8), True, None),
#  (372, 'Ernest', 'Sanyaro Raine', datetime.date(2010, 4, 30), True, None),
#  (373, 'Ellen', 'Stewart Wade', datetime.date(1976, 6, 15), True, None),
#  (374, 'Merry', 'Robinson James', datetime.date(2013, 8, 31), True, None),
#  (340, 'Mable', 'King Carney', datetime.date(1987, 11, 30), True, 32),
#  (266, 'Aida', 'Miles Lee', datetime.date(1974, 5, 29), False, 189),
#  (345, 'Reginald', 'Geimer Jones', datetime.date(2005, 11, 28), False, 988),
#  (252, 'John', 'Martinez Curtis', datetime.date(2013, 10, 30), True, 745),
#  (375, 'William', 'Meza Morgan', datetime.date(2004, 5, 24), True, 734),
#  (333, 'Amanda', 'Steele George', datetime.date(2019, 9, 4), True, 92),
#  (309, 'Jessica', 'Dooley Parris', datetime.date(1989, 8, 26), True, 483),
#  (268, 'John', 'Caras Hartman', datetime.date(1972, 6, 26), False, 963),
#  (321, 'Lisa', 'Olson Ward', datetime.date(1991, 11, 4), False, 130),
#  (279, 'Evelyn', 'Shumaker Barnes', datetime.date(2000, 2, 3), False, 181),
#  (299, 'Floyd', 'Sparkman Riley', datetime.date(1991, 1, 10), True, 46),
#  (253, 'Sonya', 'Sublett Hernandez', datetime.date(2015, 2, 28), True, 859),
#  (376, 'Gloria', 'Davis Mondesir', datetime.date(2000, 2, 8), True, None),
#  (377, 'Benjamin', 'Fiedler Savarese', datetime.date(2014, 4, 30), True, None),
#  (378, 'Karen', 'Manchester Bohringer', datetime.date(1988, 10, 31), True, None),
#  (379, 'Monty', 'Debois Vanwinkle', datetime.date(1986, 1, 4), False, None),
#  (380, 'Marcus', 'Coleman Lee', datetime.date(1989, 8, 26), True, None),
#  (381, 'Rhonda', 'Bastian Thompson', datetime.date(1978, 12, 20), False, None),
#  (382, 'William', 'Griffiths Malloy', datetime.date(2015, 8, 5), False, None),
#  (383, 'Philip', 'Perkins Rigel', datetime.date(2003, 11, 3), False, None),
#  (385, 'Wayne', 'Selley Sherman', datetime.date(1980, 6, 7), True, None),
#  (386, 'George', 'Kwan Mantooth', datetime.date(1985, 2, 1), False, None),
#  (387, 'Barbara', 'Santos Blake', datetime.date(2021, 1, 12), False, None),
#  (388, 'John', 'Mumm Woodruff', datetime.date(1976, 2, 25), True, None),
#  (389, 'Katrina', 'Mcguire Granado', datetime.date(2022, 9, 21), False, None),
#  (390, 'Roy', 'Webber Jones', datetime.date(2006, 4, 14), False, None),
#  (392, 'Lindsey', 'Kehres Strickler', datetime.date(2019, 7, 11), False, None),
#  (393, 'Theodore', 'Hackett Noyola', datetime.date(1989, 2, 5), False, None),
#  (394, 'Wm', 'Butts Riley', datetime.date(2019, 11, 23), True, None),
#  (396, 'Alice', 'Sherman Shelquist', datetime.date(2000, 12, 22), False, None),
#  (397, 'Annie', 'Marquez Pickard', datetime.date(2015, 10, 4), True, None),
#  (398, 'Sarah', 'Rosado Agustin', datetime.date(1973, 5, 31), True, None),
#  (400, 'William', 'Quist Flores', datetime.date(2018, 5, 20), True, None),
#  (401, 'Deanna', 'Westphal Musgrove', datetime.date(1993, 4, 13), False, None),
#  (402, 'Vernon', 'Thompson Blackwell', datetime.date(2014, 11, 2), False, None),
#  (403, 'James', 'Busch Davis', datetime.date(1990, 2, 17), False, None),
#  (404, 'Dian', 'Allen Klingbeil', datetime.date(1998, 2, 13), True, None),
#  (406, 'William', 'Bowen Hoyos', datetime.date(2006, 2, 20), True, None),
#  (409, 'Jeffrey', 'Bunch Bayer', datetime.date(2006, 11, 3), True, None),
#  (410, 'Beth', 'Wheeler Mcdonald', datetime.date(1989, 3, 4), False, None),
#  (412, 'Robert', 'Jones Scott', datetime.date(1989, 10, 13), False, None),
#  (413, 'Kathy', 'Swanhart Ayers', datetime.date(1982, 6, 17), False, None),
#  (414, 'Byron', 'Carstarphen Mester', datetime.date(1988, 1, 2), True, None),
#  (415, 'Charlotte', 'Coble Banks', datetime.date(1972, 12, 1), False, None),
#  (416, 'Booker', 'Shimer Vallejo', datetime.date(2012, 3, 19), False, None),
#  (417, 'William', 'Howell Collins', datetime.date(2001, 8, 9), True, None),
#  (418, 'Velma', 'Wester Fields', datetime.date(2011, 9, 26), True, None),
#  (419, 'Janis', 'Disimone Hanson', datetime.date(1973, 4, 30), False, None),
#  (420, 'James', 'Conner Carroll', datetime.date(1977, 7, 26), True, None),
#  (421, 'Jennifer', 'Braswell Robinette', datetime.date(1970, 8, 10), False, None),
#  (422, 'Brenda', 'Espinosa Walker', datetime.date(2017, 1, 22), True, None),
#  (425, 'Douglas', 'Infield Gregory', datetime.date(1998, 1, 8), False, None),
#  (426, 'Marry', 'Wilcox Nelson', datetime.date(1993, 9, 24), False, None),
#  (427, 'Kevin', 'Dietzler Batiste', datetime.date(1983, 6, 26), True, None),
#  (428, 'James', 'Lopez Munoz', datetime.date(1973, 5, 4), True, None),
#  (429, 'Anna', 'Abernathy Deboer', datetime.date(2011, 7, 6), True, None),
#  (430, 'Monica', 'Leach Nickerson', datetime.date(1980, 5, 15), False, None),
#  (431, 'Ernie', 'Sullivan Hundley', datetime.date(1995, 4, 8), False, None),
#  (432, 'Brian', 'Fillare Coney', datetime.date(2012, 8, 7), True, None),
#  (433, 'Natalie', 'Gamache Gettinger', datetime.date(1998, 11, 11), False, None),
#  (435, 'Mary', 'Deal Stewart', datetime.date(1991, 1, 2), True, None),
#  (436, 'Catherine', 'Ross Redding', datetime.date(1982, 7, 3), True, None),
#  (437, 'Peter', 'Butler Duarte', datetime.date(2019, 6, 28), True, None),
#  (438, 'Farrah', 'Biederman Metz', datetime.date(2019, 5, 10), False, None),
#  (439, 'Brad', 'Snowden Doe', datetime.date(1990, 4, 2), False, None),
#  (440, 'Paul', 'Gallegos Welch', datetime.date(1987, 11, 12), True, None),
#  (441, 'Mack', 'Hargrove Miller', datetime.date(2022, 12, 25), True, None),
#  (442, 'Daniel', 'Isenhart Burks', datetime.date(1973, 5, 4), False, None),
#  (443, 'Terry', 'Rickley Yoo', datetime.date(2002, 12, 30), True, None),
#  (444, 'Linda', 'Perry Ohmen', datetime.date(1996, 5, 20), True, None),
#  (446, 'Donna', 'Welch Lowers', datetime.date(1983, 2, 11), False, None),
#  (447, 'Karen', 'Zable Lopez', datetime.date(2003, 5, 3), False, None),
#  (448, 'Tara', 'Baron Capps', datetime.date(1979, 9, 16), False, None),
#  (450, 'Tracy', 'Brunkhorst Olmstead', datetime.date(2018, 5, 22), False, None),
#  (451, 'Sandy', 'Abreu Tarr', datetime.date(2011, 5, 24), False, None),
#  (452, 'Wayne', 'Okafor Young', datetime.date(1990, 4, 5), True, None),
#  (454, 'William', 'Spore Bunda', datetime.date(2002, 9, 13), False, None),
#  (455, 'Ben', 'Smith Auckerman', datetime.date(2018, 6, 5), False, None),
#  (456, 'Justin', 'Derosier Blue', datetime.date(2019, 6, 12), False, None),
#  (457, 'Yvette', 'Silvers Chapman', datetime.date(2013, 3, 31), True, None),
#  (458, 'Marc', 'Bennett Smith', datetime.date(2017, 7, 21), True, None),
#  (459, 'Henry', 'Mcclain Marcano', datetime.date(2010, 7, 30), False, None),
#  (460, 'William', 'Stamps Crabtree', datetime.date(1976, 3, 17), True, None),
#  (461, 'John', 'Crawford Kim', datetime.date(1980, 9, 22), True, None),
#  (462, 'Tanya', 'Burt Dougherty', datetime.date(2017, 8, 8), True, None),
#  (463, 'Evon', 'Kabrick Kennedy', datetime.date(2015, 12, 6), True, None),
#  (464, 'Sandra', 'Miltenberger Cecena', datetime.date(1991, 9, 27), False, None),
#  (465, 'Nancy', 'Bartlett Fettig', datetime.date(1992, 1, 16), True, None),
#  (466, 'Allen', 'Jones Jordon', datetime.date(2015, 12, 28), False, None),
#  (467, 'Charles', 'Veyna Rector', datetime.date(1993, 3, 4), False, None),
#  (468, 'Bonnie', 'Kirchner Gosa', datetime.date(2020, 10, 15), True, None),
#  (469, 'Kevin', 'Grosbier Vallejo', datetime.date(1971, 2, 17), True, None),
#  (470, 'Kelvin', 'Baez Renaud', datetime.date(1980, 12, 18), False, None),
#  (471, 'Pamela', 'Ford Snow', datetime.date(1994, 7, 10), False, None),
#  (472, 'Kevin', 'Swanson Bell', datetime.date(1994, 11, 16), True, None),
#  (473, 'Cecile', 'Coffin Krueger', datetime.date(2005, 4, 6), False, None),
#  (474, 'Walter', 'Hattabaugh Parrish', datetime.date(1980, 1, 8), True, None),
#  (475, 'David', 'Pinckney Catania', datetime.date(1979, 2, 7), True, None),
#  (476, 'Pauline', 'Ramos Harris', datetime.date(2008, 6, 9), True, None),
#  (477, 'Sarah', 'Serrano Hirata', datetime.date(2015, 2, 28), False, None),
#  (478, 'Ted', 'York Fortunato', datetime.date(1998, 10, 16), True, None),
#  (479, 'Dan', 'Heuer Landis', datetime.date(2019, 11, 3), True, None),
#  (480, 'John', 'Gross Shepperd', datetime.date(1994, 9, 15), True, None),
#  (481, 'James', 'Mcintosh Detrick', datetime.date(2017, 7, 25), False, None),
#  (482, 'Eddie', 'Truman Roach', datetime.date(1999, 8, 21), True, None),
#  (484, 'Chris', 'Mattern Turner', datetime.date(2007, 3, 6), True, None),
#  (485, 'Robert', 'Chapman Carter', datetime.date(2000, 8, 29), True, None),
#  (486, 'Gary', 'Brown Tanaka', datetime.date(1984, 3, 10), True, None),
#  (487, 'Lucien', 'Kane Smith', datetime.date(1976, 4, 28), False, None),
#  (488, 'Lena', 'Stephens Blair', datetime.date(1980, 6, 26), False, None),
#  (489, 'Johnny', 'Findlay Carlson', datetime.date(1976, 9, 25), True, None),
#  (490, 'James', 'Schaffer Hutchens', datetime.date(1973, 9, 18), True, None),
#  (491, 'Karen', 'Fellin Mccabe', datetime.date(1980, 7, 24), False, None),
#  (492, 'Lawanda', 'Graham Waller', datetime.date(1977, 3, 15), False, None),
#  (495, 'Tiffany', 'Ewing Thelen', datetime.date(2017, 7, 16), False, None),
#  (496, 'Lakisha', 'Lewis Murray', datetime.date(2019, 6, 3), False, None),
#  (497, 'Robert', 'Miller Pineda', datetime.date(1976, 6, 1), False, None),
#  (498, 'Stephen', 'Blackmon Thomas', datetime.date(2013, 12, 18), True, None),
#  (499, 'Alyce', 'King Wallace', datetime.date(2006, 8, 18), False, None),
#  (494, 'Joe', 'Morris Carey', datetime.date(2013, 8, 18), True, 561),
#  (449, 'Tanya', 'Pregler Culler', datetime.date(1971, 11, 11), True, 150),
#  (501, 'Sandra', 'Stern Hardin', datetime.date(2015, 2, 21), True, 106),
#  (445, 'Dave', 'Gostlin Orton', datetime.date(1982, 9, 22), False, 587),
#  (408, 'Mary', 'Saeler Breed', datetime.date(1985, 4, 8), True, 919),
#  (434, 'Penny', 'Goff Gilliam', datetime.date(2005, 8, 20), True, 815),
#  (399, 'Barbara', 'Vann Vanicek', datetime.date(2015, 11, 7), True, 856),
#  (483, 'Andres', 'Greene Haggard', datetime.date(1988, 2, 3), True, 309),
#  (391, 'Alvin', 'Angel Tonner', datetime.date(1996, 7, 13), False, 662),
#  (423, 'Joan', 'Harris Knutson', datetime.date(2012, 3, 21), False, 144),
#  (405, 'Alma', 'Park Kemp', datetime.date(1973, 6, 9), True, 618),
#  (384, 'Abby', 'Denise Meyer', datetime.date(1985, 2, 2), False, 953),
#  (395, 'Dominick', 'Burns Hager', datetime.date(1983, 1, 31), True, 99),
#  (407, 'Michael', 'Perry Adams', datetime.date(2012, 9, 24), True, 500),
#  (453, 'Wanda', 'Ack Boulch', datetime.date(2012, 12, 15), False, 84),
#  (502, 'Leslie', 'Stuer Coleman', datetime.date(1998, 6, 30), False, None),
#  (503, 'Eileen', 'Stanley Jaegers', datetime.date(1998, 4, 3), True, None),
#  (505, 'Nick', 'Pimentel Taylor', datetime.date(1971, 8, 9), True, None),
#  (506, 'Lorenza', 'Allison Kun', datetime.date(1990, 9, 12), False, None),
#  (507, 'George', 'Martin Black', datetime.date(1998, 4, 3), False, None),
#  (508, 'James', 'Welch Thomas', datetime.date(1997, 3, 31), True, None),
#  (509, 'Jeffrey', 'Miller Reed', datetime.date(1987, 6, 22), True, None),
#  (511, 'Jorge', 'Greenberg Williams', datetime.date(1983, 5, 13), True, None),
#  (512, 'Earl', 'Lederer Martinez', datetime.date(1992, 3, 6), True, None),
#  (513, 'Clint', 'Kolden Wall', datetime.date(1990, 10, 16), True, None),
#  (514, 'Mollie', 'Christianson Dugan', datetime.date(2009, 9, 14), False, None),
#  (516, 'Steven', 'Irby Thielen', datetime.date(2017, 2, 25), False, None),
#  (517, 'Colleen', 'Graves Harris', datetime.date(1991, 10, 27), True, None),
#  (518, 'Christopher', 'Stiffler Karter', datetime.date(1972, 8, 8), True, None),
#  (519, 'Donald', 'Booth Garcia', datetime.date(1987, 9, 30), True, None),
#  (520, 'Mary', 'Sweeny Baker', datetime.date(1992, 7, 5), True, None),
#  (521, 'Justin', 'Andrews Ortega', datetime.date(2008, 11, 24), False, None),
#  (522, 'Michael', 'Conrad Masson', datetime.date(2000, 8, 3), False, None),
#  (523, 'Carla', 'Jimenez Garcia', datetime.date(1989, 6, 9), True, None),
#  (524, 'Eric', 'Curtis Fisk', datetime.date(1978, 4, 30), True, None),
#  (525, 'Debra', 'Frazier Thissen', datetime.date(2011, 8, 19), False, None),
#  (526, 'Claire', 'Leslie Walters', datetime.date(2007, 2, 9), False, None),
#  (527, 'Guillermo', 'Romero Thornton', datetime.date(1999, 2, 11), False, None),
#  (528, 'Kelly', 'Tipler Bush', datetime.date(2021, 4, 9), False, None),
#  (529, 'Robert', 'Wood Doles', datetime.date(2021, 7, 4), False, None),
#  (530, 'Jerrie', 'Howard Berthelette', datetime.date(1973, 3, 21), False, None),
#  (531, 'Anne', 'Brown Ramirez', datetime.date(2017, 9, 12), False, None),
#  (532, 'William', 'Altizer Fritz', datetime.date(1995, 2, 10), False, None),
#  (533, 'Frank', 'Olsen Lincoln', datetime.date(1974, 5, 2), False, None),
#  (534, 'Virginia', 'Johnson Halcomb', datetime.date(1975, 5, 12), True, None),
#  (535, 'Elizabeth', 'Fields Jones', datetime.date(2018, 8, 31), False, None),
#  (536, 'Kathy', 'Appling Harris', datetime.date(1980, 10, 31), True, None),
#  (537, 'Marvin', 'Mcbee Parrott', datetime.date(2012, 9, 20), False, None),
#  (538, 'Mary', 'Smith Mitcham', datetime.date(1973, 1, 25), False, None),
#  (539, 'Mitchell', 'Brown Barker', datetime.date(2002, 2, 16), True, None),
#  (540, 'Sonja', 'Topps Pick', datetime.date(1994, 11, 11), False, None),
#  (541, 'Hector', 'Donahue Garza', datetime.date(1981, 8, 13), True, None),
#  (544, 'Keith', 'Zimmerman Wong', datetime.date(2021, 10, 13), True, None),
#  (546, 'Robert', 'Zaccaria Mcclary', datetime.date(1976, 11, 8), False, None),
#  (548, 'Edward', 'Cox Kane', datetime.date(1994, 2, 20), True, None),
#  (550, 'Chung', 'Caudill Diven', datetime.date(1993, 4, 9), False, None),
#  (551, 'Jesus', 'Young Springer', datetime.date(1980, 2, 28), False, None),
#  (552, 'Sherrell', 'Mckown Weir', datetime.date(1973, 12, 30), True, None),
#  (553, 'Robert', 'Adon Diekmann', datetime.date(1987, 10, 28), False, None),
#  (555, 'Norman', 'Quick Edwards', datetime.date(2013, 11, 25), False, None),
#  (556, 'Jill', 'Burrows Self', datetime.date(2016, 11, 17), True, None),
#  (557, 'Nannie', 'Barker Clark', datetime.date(1989, 11, 2), False, None),
#  (558, 'Phillip', 'Alessi Jenness', datetime.date(1972, 2, 6), True, None),
#  (559, 'Ruth', 'Baker Perry', datetime.date(1993, 7, 10), True, None),
#  (560, 'Lula', 'Bradley Hering', datetime.date(1976, 1, 28), True, None),
#  (562, 'Brittney', 'Turner Manheim', datetime.date(1980, 11, 7), True, None),
#  (563, 'Jana', 'Mees Greenwood', datetime.date(1985, 3, 5), False, None),
#  (564, 'Robert', 'Bowers Mcgregor', datetime.date(1988, 4, 20), False, None),
#  (565, 'Mark', 'Cooper Daves', datetime.date(1971, 11, 3), False, None),
#  (567, 'Rachel', 'Thomas Jeffrey', datetime.date(1974, 7, 25), False, None),
#  (568, 'Kellie', 'Jones Toenges', datetime.date(2022, 6, 13), False, None),
#  (569, 'Dan', 'Patterson Kilpatrick', datetime.date(1986, 9, 30), False, None),
#  (570, 'Elizabeth', 'Vess Smith', datetime.date(1996, 12, 15), False, None),
#  (571, 'David', 'Bessler Burnett', datetime.date(2000, 9, 30), False, None),
#  (572, 'Richard', 'Songer Dean', datetime.date(2009, 12, 29), True, None),
#  (573, 'Daniel', 'Smithson Bacon', datetime.date(1986, 9, 18), False, None),
#  (574, 'Erica', 'Reiss Lewis', datetime.date(1997, 1, 13), False, None),
#  (575, 'Anita', 'Nix Helt', datetime.date(2019, 3, 12), True, None),
#  (576, 'Caridad', 'Webb Kathleen', datetime.date(1987, 4, 25), False, None),
#  (577, 'Regina', 'Doyle Schneider', datetime.date(2001, 12, 9), True, None),
#  (578, 'Anthony', 'Lynch Litteral', datetime.date(1995, 4, 12), True, None),
#  (579, 'Brady', 'Miller Wohner', datetime.date(1981, 12, 22), False, None),
#  (580, 'Lon', 'Cruz Smith', datetime.date(1976, 1, 26), True, None),
#  (581, 'Latrice', 'Mcelroy Brown', datetime.date(2002, 1, 31), True, None),
#  (582, 'Clifford', 'Kelley Fino', datetime.date(1983, 12, 5), True, None),
#  (583, 'Deborah', 'Mccracken Higgs', datetime.date(1994, 5, 19), True, None),
#  (584, 'Chester', 'Cox Dudley', datetime.date(1973, 8, 3), True, None),
#  (585, 'Robert', 'Balius Krug', datetime.date(1972, 6, 27), False, None),
#  (586, 'Michael', 'Ortiz Bice', datetime.date(2020, 2, 7), True, None),
#  (589, 'Lori', 'Mcgee Smith', datetime.date(1995, 2, 15), True, None),
#  (590, 'Jocelyn', 'Yarbrough Frizzell', datetime.date(1995, 10, 8), False, None),
#  (591, 'Pat', 'Vela Ledesma', datetime.date(2004, 9, 3), True, None),
#  (592, 'William', 'Hoyt Wilson', datetime.date(1986, 1, 9), False, None),
#  (594, 'Dorothy', 'Aguirre Pierce', datetime.date(2016, 9, 26), False, None),
#  (595, 'Anne', 'Burkholder Vargas', datetime.date(1984, 7, 5), True, None),
#  (597, 'Nancy', 'Carroll Mervis', datetime.date(1994, 12, 15), False, None),
#  (598, 'Joshua', 'Wilson Caldwell', datetime.date(2004, 11, 10), False, None),
#  (599, 'Ann', 'Terry Lavoie', datetime.date(1986, 8, 30), False, None),
#  (600, 'Alphonso', 'Roberts Cole', datetime.date(1990, 3, 24), False, None),
#  (603, 'Claire', 'Kemp Morton', datetime.date(1970, 6, 20), False, None),
#  (604, 'Elizabeth', 'Elliott Austin', datetime.date(2006, 8, 22), True, None),
#  (605, 'Norman', 'Piccolomini Williams', datetime.date(1988, 1, 17), True, None),
#  (606, 'Karina', 'Kim Wollschlager', datetime.date(1981, 3, 8), False, None),
#  (607, 'Dorthy', 'Lemle Giebler', datetime.date(1971, 5, 24), True, None),
#  (608, 'Lorene', 'Hill Hays', datetime.date(1982, 7, 15), True, None),
#  (609, 'Rose', 'Pace Davis', datetime.date(1995, 10, 8), False, None),
#  (610, 'George', 'Degroat Espinosa', datetime.date(1999, 4, 21), True, None),
#  (611, 'Santo', 'Goldberg Kealoha', datetime.date(1974, 8, 22), False, None),
#  (612, 'Louis', 'Hoffman Mcclimon', datetime.date(2001, 5, 3), True, None),
#  (613, 'Luis', 'Mclaughlin Cho', datetime.date(1973, 10, 28), False, None),
#  (615, 'James', 'Harvey Sanders', datetime.date(1976, 1, 24), False, None),
#  (616, 'John', 'Rodriguez Buehlman', datetime.date(1983, 11, 4), False, None),
#  (617, 'Heather', 'Sorell Sanders', datetime.date(1990, 10, 22), True, None),
#  (620, 'Scott', 'Stamm Sena', datetime.date(2006, 5, 3), True, None),
#  (623, 'Sam', 'Delcastillo Noble', datetime.date(1996, 1, 12), True, None),
#  (624, 'Blair', 'Perry Williams', datetime.date(1983, 4, 6), True, None),
#  (625, 'Sharon', 'Lumsden Duffy', datetime.date(1998, 11, 5), True, None),
#  (626, 'Mary', 'Maselli Pedregon', datetime.date(1980, 9, 19), False, None),
#  (593, 'Charles', 'Garcia Hall', datetime.date(1996, 1, 25), True, 939),
#  (621, 'Peter', 'Sanchez Mcnutt', datetime.date(1986, 9, 13), True, 950),
#  (614, 'Genaro', 'Sledge Papa', datetime.date(2002, 8, 26), True, 549),
#  (547, 'Traci', 'Elmore Tackett', datetime.date(1980, 11, 23), True, 788),
#  (566, 'James', 'Reed Jaramillo', datetime.date(1973, 5, 6), False, 757),
#  (504, 'Shelia', 'Wigington Bailey', datetime.date(1996, 12, 7), True, 71),
#  (602, 'Shannon', 'Pierson Williams', datetime.date(2013, 10, 7), True, 127),
#  (542, 'John', 'Torres Reynolds', datetime.date(2011, 8, 20), True, 699),
#  (587, 'Nicholas', 'Miller Davis', datetime.date(1978, 12, 19), True, 445),
#  (619, 'Jeffrey', 'Rasmussen Donson', datetime.date(2015, 3, 10), False, 796),
#  (601, 'Fern', 'Wellman Wahba', datetime.date(2002, 2, 12), False, 588),
#  (543, 'Kerrie', 'Mccloud Delgado', datetime.date(1996, 7, 8), True, 653),
#  (554, 'Ana', 'Rodriguez Weisman', datetime.date(2015, 10, 2), False, 824),
#  (596, 'Maria', 'Mcclellan Bitter', datetime.date(2014, 6, 23), False, 894),
#  (618, 'Ramona', 'Mcknight Williams', datetime.date(2003, 6, 3), True, 405),
#  (545, 'George', 'Jimison Roylance', datetime.date(1984, 9, 15), False, 892),
#  (515, 'Ray', 'Hanscom Puentes', datetime.date(1980, 6, 18), False, 938),
#  (622, 'Christina', 'Martinez Abel', datetime.date(1979, 2, 28), True, 510),
#  (627, 'Belinda', 'Moore Smith', datetime.date(2019, 9, 14), False, None),
#  (629, 'Michael', 'Stover Walls', datetime.date(1973, 3, 10), False, None),
#  (630, 'Robert', 'Hernandez Burnette', datetime.date(1998, 4, 9), True, None),
#  (631, 'Jeffrey', 'Rhyne Russell', datetime.date(1976, 10, 9), True, None),
#  (632, 'John', 'Huttar Chapman', datetime.date(1972, 5, 1), False, None),
#  (633, 'Amy', 'Caudle Beard', datetime.date(1990, 6, 28), True, None),
#  (634, 'Mary', 'Anderson Satchell', datetime.date(2010, 8, 14), True, None),
#  (635, 'Linda', 'Holderfield Withers', datetime.date(2012, 2, 28), False, None),
#  (636, 'Michael', 'Jackson Hoyle', datetime.date(1989, 10, 23), True, None),
#  (637, 'Michelle', 'Lombardo Meadows', datetime.date(1982, 8, 1), False, None),
#  (638, 'Karen', 'Sessions Dubose', datetime.date(1994, 1, 17), True, None),
#  (639, 'Michael', 'Lyons Stevens', datetime.date(1972, 10, 16), False, None),
#  (641, 'Thomas', 'Osteen Ohara', datetime.date(1991, 12, 30), False, None),
#  (642, 'Brian', 'Mason Bass', datetime.date(1981, 12, 12), True, None),
#  (643, 'Roberto', 'Blake Metcalfe', datetime.date(1974, 8, 5), True, None),
#  (644, 'Francis', 'Sears Rarden', datetime.date(2013, 11, 6), True, None),
#  (645, 'Chelsea', 'Creekmore Greene', datetime.date(2006, 2, 23), False, None),
#  (646, 'Lowell', 'Williams Garcia', datetime.date(2012, 11, 1), False, None),
#  (647, 'Tana', 'Stapleton Mcgarry', datetime.date(2003, 8, 29), False, None),
#  (648, 'John', 'Lambdin Nims', datetime.date(1976, 9, 9), False, None),
#  (649, 'John', 'Robinson Cowell', datetime.date(1984, 5, 17), True, None),
#  (650, 'Gladys', 'Rawlins Bunch', datetime.date(1985, 1, 14), True, None),
#  (651, 'Alicia', 'Montoya Borrego', datetime.date(2014, 3, 18), True, None),
#  (652, 'Stacey', 'Moseley Seitz', datetime.date(1986, 10, 31), False, None),
#  (654, 'Tenisha', 'Vanhorne Culver', datetime.date(1983, 5, 27), True, None),
#  (655, 'Sherri', 'Mayer Rowe', datetime.date(1977, 4, 27), True, None),
# ...
#  (820, 'Ernest', 'Ross Fisher', datetime.date(1972, 9, 21), False, None),
#  (821, 'Janet', 'Bales Kallenberg', datetime.date(1983, 2, 7), True, None),
#  (822, 'Nathaniel', 'Nielsen Daughtry', datetime.date(1987, 8, 15), False, None),
#  (823, 'Tamara', 'Mills Littleton', datetime.date(1979, 8, 4), True, None),
#  (825, 'Christopher', 'Kinnaman Cheek', datetime.date(2010, 4, 18), False, None),
#  (826, 'James', 'Ramerez Tucker', datetime.date(1979, 2, 8), False, None),
#  (827, 'Laurie', 'Ruffin White', datetime.date(2007, 12, 2), False, None),
#  (828, 'Lyle', 'Armstong Hoffman', datetime.date(1976, 4, 21), False, None),
#  (830, 'Dorothy', 'Prager Weir', datetime.date(2016, 12, 29), True, None),
#  (831, 'Ricardo', 'Jenks Collins', datetime.date(2000, 3, 25), True, None),
#  (832, 'Paul', 'Feuerborn Garza', datetime.date(2011, 5, 9), False, None),
#  (833, 'Sylvia', 'Perkins Mccrimmon', datetime.date(1983, 6, 6), True, None),
#  (835, 'Michael', 'Shepard Chow', datetime.date(2008, 8, 21), True, None),
#  (836, 'Bradford', 'Miller Greene', datetime.date(1997, 1, 9), True, None),
#  (838, 'Edward', 'Robinson Starr', datetime.date(1994, 1, 22), True, None),
#  (839, 'Joshua', 'Weisgerber Villatora', datetime.date(1973, 12, 6), True, None),
#  (840, 'Joseph', 'Walker Salano', datetime.date(1978, 5, 26), True, None),
#  (841, 'Gene', 'Marlow House', datetime.date(2006, 11, 5), False, None),
#  (842, 'Carmen', 'Bedsole Richins', datetime.date(2008, 6, 11), True, None),
#  (843, 'Kenneth', 'Whitten Conti', datetime.date(2003, 4, 30), True, None),
#  (844, 'Jackson', 'Strange Cummings', datetime.date(1985, 9, 3), True, None),
#  (845, 'Wilfred', 'Grubb Ridgeway', datetime.date(1984, 12, 29), False, None),
#  (846, 'Patricia', 'Davis Humphreys', datetime.date(2007, 11, 5), False, None),
#  (847, 'Kenneth', 'Thomas Virula', datetime.date(1972, 1, 23), False, None),
#  (848, 'Alfonso', 'Ehrgott Jackson', datetime.date(1992, 7, 13), True, None),
#  (849, 'Alfred', 'Manrique Williams', datetime.date(1972, 1, 25), True, None),
#  (850, 'Kenneth', 'Lucas Baez', datetime.date(1971, 12, 9), True, None),
#  (852, 'Jason', 'Nelson Jackson', datetime.date(1984, 10, 10), False, None),
#  (853, 'Keith', 'Ramos Luna', datetime.date(1984, 4, 27), True, None),
#  (854, 'Courtney', 'Galloway Ashley', datetime.date(1985, 8, 31), True, None),
#  (855, 'Frank', 'Bond Duckett', datetime.date(2013, 9, 20), True, None),
#  (858, 'Matthew', 'Ashburn Gay', datetime.date(1996, 6, 11), False, None),
#  (860, 'Jackie', 'Basye Anderson', datetime.date(1977, 3, 27), True, None),
#  (861, 'Irene', 'Mayfield Hartsfield', datetime.date(2017, 12, 4), False, None),
#  (862, 'Derek', 'Cone Pratt', datetime.date(2011, 7, 24), False, None),
#  (863, 'Louise', 'Stokes Fitzgerald', datetime.date(2022, 6, 26), False, None),
#  (864, 'Sandra', 'Patten Slade', datetime.date(1977, 12, 14), False, None),
#  (865, 'Latanya', 'Novetsky Ward', datetime.date(1985, 6, 23), True, None),
#  (868, 'Lynn', 'Gonzales Wilhoite', datetime.date(1994, 12, 6), True, None),
#  (869, 'Eugene', 'Harold Holland', datetime.date(2005, 8, 19), True, None),
#  (871, 'Mary', 'Maxey Dagley', datetime.date(2016, 6, 19), True, None),
#  (872, 'Robert', 'Glass Jankowiak', datetime.date(1998, 4, 14), True, None),
#  (873, 'Jimmie', 'Jaudon Aronowitz', datetime.date(2000, 8, 15), True, None),
#  (875, 'Kari', 'Moulden Godwin', datetime.date(2004, 3, 15), False, None),
#  (877, 'Marguerite', 'Johnson Howard', datetime.date(2010, 8, 8), False, None),
#  (874, 'Tracy', 'Hopper Harris', datetime.date(1988, 3, 31), True, 153),
#  (867, 'Deborah', 'Mcculloch Rodriguez', datetime.date(2016, 8, 17), False, 834),
#  (764, 'Richard', 'Myatt Viverette', datetime.date(1996, 1, 23), False, 712),
#  (788, 'Kerry', 'Allen Keller', datetime.date(1993, 6, 6), False, 547),
#  (757, 'Jason', 'Raheja Burris', datetime.date(1978, 5, 19), False, 566),
#  (778, 'Douglas', 'Vahey Grant', datetime.date(1981, 6, 1), False, 493),
#  (785, 'Damian', 'Vanhook Pettit', datetime.date(2021, 3, 23), True, 876),
#  (761, 'George', 'Rinck Howard', datetime.date(1973, 10, 21), False, 628),
#  (851, 'Ninfa', 'Duran Keefer', datetime.date(1976, 1, 30), False, 168),
#  (800, 'Robert', 'Williams Jones', datetime.date(2019, 6, 30), True, 657),
#  (815, 'Jose', 'Robinson Lainhart', datetime.date(1977, 10, 13), False, 434),
#  (856, 'Troy', 'Stellhorn Carlin', datetime.date(1974, 4, 29), True, 399),
#  (796, 'Debra', 'Jacob Spurling', datetime.date(2007, 2, 4), True, 619),
#  (866, 'Robert', 'Vera Daulton', datetime.date(2013, 1, 31), True, 956),
#  (829, 'Gale', 'Stefanatos Miller', datetime.date(1970, 1, 10), False, 351),
#  (824, 'Christine', 'Thomas Goodrow', datetime.date(1974, 4, 19), True, 554),
#  (859, 'Robert', 'Wainscott Limon', datetime.date(1972, 12, 6), False, 253),
#  (765, 'Diana', 'Long Haines', datetime.date(2010, 5, 26), True, 109),
#  (837, 'Norma', 'Watts Smith', datetime.date(1989, 12, 1), False, 658),
#  (878, 'Brandie', 'Whyte Jones', datetime.date(1999, 2, 1), True, None),
#  (879, 'Carol', 'Knight Lantz', datetime.date(1995, 1, 17), True, None),
#  (880, 'Wayne', 'Bailey Dean', datetime.date(2019, 2, 21), False, None),
#  (881, 'Margie', 'Woods Powers', datetime.date(2007, 4, 6), True, None),
#  (882, 'Scott', 'Jensen Ziego', datetime.date(2003, 7, 24), False, None),
#  (883, 'Brandy', 'Harper Horton', datetime.date(2003, 1, 28), True, None),
#  (884, 'Jaime', 'Cooke Gentry', datetime.date(1988, 4, 23), True, None),
#  (885, 'Diana', 'Stutz Bloomer', datetime.date(1997, 5, 9), True, None),
#  (886, 'Eric', 'Brady Pinera', datetime.date(1992, 5, 16), False, None),
#  (888, 'Christopher', 'Davis Rumberger', datetime.date(1980, 1, 25), True, None),
#  (889, 'James', 'Gutierrez Foster', datetime.date(2013, 2, 6), True, None),
#  (890, 'Marjorie', 'Tillman Fraser', datetime.date(1973, 3, 2), True, None),
#  (891, 'Richard', 'Bullington Wiese', datetime.date(2011, 7, 13), False, None),
#  (893, 'Annie', 'Wilson Porter', datetime.date(1984, 1, 8), False, None),
#  (895, 'Jack', 'James Newlin', datetime.date(2012, 11, 30), False, None),
#  (896, 'Henry', 'Bailey Tran', datetime.date(2007, 11, 24), False, None),
#  (897, 'Garrett', 'Walter Davis', datetime.date(1995, 1, 13), True, None),
#  (898, 'Eleanor', 'Capps Rivas', datetime.date(1977, 1, 4), True, None),
#  (899, 'Lori', 'Fields Fischer', datetime.date(1974, 5, 22), False, None),
#  (901, 'Amy', 'Chase Alberson', datetime.date(1982, 7, 9), False, None),
#  (902, 'Willie', 'Osdoba Gonzales', datetime.date(1990, 9, 4), True, None),
#  (903, 'Nereida', 'Pontiff Casavant', datetime.date(1995, 4, 10), True, None),
#  (904, 'Bessie', 'Faulk Barnes', datetime.date(2011, 3, 7), True, None),
#  (906, 'Scott', 'Key Arnett', datetime.date(1988, 10, 28), True, None),
#  (907, 'Tracey', 'Quarry Weathers', datetime.date(2020, 3, 25), False, None),
#  (908, 'John', 'Kilmer Rodriguez', datetime.date(2018, 6, 27), True, None),
#  (909, 'Wilbert', 'Weaver Polk', datetime.date(1990, 5, 24), True, None),
#  (910, 'Gabriel', 'Guzman Lawson', datetime.date(1996, 9, 27), False, None),
#  (911, 'Cindy', 'Hook White', datetime.date(2003, 8, 8), True, None),
#  (912, 'William', 'Golden Porter', datetime.date(2002, 5, 22), False, None),
#  (914, 'Lucille', 'Barton Diaz', datetime.date(1971, 4, 29), False, None),
#  (915, 'Alexander', 'Cheng Crook', datetime.date(2008, 8, 12), True, None),
#  (916, 'Dorothy', 'Blankenship Cowell', datetime.date(1972, 12, 9), True, None),
#  (917, 'Johnny', 'Luma Terrill', datetime.date(2015, 8, 18), False, None),
#  (918, 'Kathy', 'Jordan Dietrich', datetime.date(1998, 12, 8), False, None),
#  (920, 'Audrey', 'Burrows Echard', datetime.date(1989, 3, 24), False, None),
#  (921, 'Donald', 'Swanson Lansing', datetime.date(1986, 1, 17), False, None),
#  (922, 'Camille', 'Scanlan Mahone', datetime.date(2022, 3, 22), True, None),
#  (923, 'John', 'Klein Cardwell', datetime.date(1987, 4, 9), False, None),
#  (924, 'Amy', 'Shepherd Jinks', datetime.date(1981, 8, 9), True, None),
#  (925, 'Larry', 'Lucius Kezar', datetime.date(1999, 8, 11), True, None),
#  (926, 'Joe', 'Quinonez Shelton', datetime.date(1988, 4, 7), False, None),
#  (929, 'Beatrice', 'Freeman Mcguire', datetime.date(1987, 6, 30), False, None),
#  (930, 'Virginia', 'Anderson Powell', datetime.date(1987, 5, 10), True, None),
#  (931, 'Tonya', 'Hoskins Balius', datetime.date(2015, 9, 28), True, None),
#  (933, 'Robert', 'Heath Miller', datetime.date(1989, 8, 12), True, None),
#  (934, 'Laronda', 'Kilpatrick Theriault', datetime.date(1978, 9, 27), True, None),
#  (935, 'Jeffrey', 'Parsons Stankiewicz', datetime.date(1997, 9, 30), False, None),
#  (936, 'William', 'Baker Fields', datetime.date(1993, 2, 28), True, None),
#  (937, 'Jean', 'Scott Waites', datetime.date(2004, 2, 17), False, None),
#  (940, 'Mary', 'Cooper Nanney', datetime.date(2002, 7, 12), False, None),
#  (941, 'Lillian', 'Greenhoward White', datetime.date(1999, 8, 5), True, None),
#  (942, 'Miriam', 'Williamson Whitenton', datetime.date(1985, 8, 2), True, None),
#  (943, 'Brady', 'Kowalcyk Busch', datetime.date(1976, 3, 5), False, None),
#  (944, 'Michael', 'Bren Lewis', datetime.date(1976, 5, 5), True, None),
#  (946, 'Michael', 'Castello Horan', datetime.date(1996, 4, 14), False, None),
#  (948, 'Robert', 'Rolon Brinson', datetime.date(1997, 1, 11), False, None),
#  (949, 'Joseph', 'Perry Rodrigue', datetime.date(1973, 8, 16), False, None),
#  (951, 'Marcus', 'Spencer Ashlock', datetime.date(2017, 5, 16), False, None),
#  (952, 'Rob', 'Oswald Mills', datetime.date(1971, 2, 6), True, None),
#  (954, 'Maryann', 'Rodrequez Ragland', datetime.date(2004, 11, 12), True, None),
#  (955, 'Jose', 'Sommer Lloyd', datetime.date(2019, 11, 18), False, None),
#  (958, 'Cecilia', 'Dotson Oliver', datetime.date(1978, 8, 25), True, None),
#  (959, 'Steven', 'Klein Conkle', datetime.date(2019, 9, 17), False, None),
#  (960, 'Julie', 'Bullock Chandler', datetime.date(2021, 3, 25), False, None),
#  (961, 'Eugena', 'Voorhees Bays', datetime.date(2017, 7, 16), False, None),
#  (962, 'Hazel', 'Camargo Viles', datetime.date(2002, 4, 20), True, None),
#  (964, 'Joseph', 'Packwood Hankins', datetime.date(1987, 6, 22), True, None),
#  (965, 'Steven', 'Tomasino Carter', datetime.date(1985, 9, 8), True, None),
#  (966, 'Patricia', 'Lopez Iglesias', datetime.date(1992, 5, 5), True, None),
#  (967, 'Tina', 'Ivan Matthews', datetime.date(1987, 12, 13), False, None),
#  (968, 'Bonnie', 'Layton Thomas', datetime.date(2005, 10, 8), True, None),
#  (970, 'Charlie', 'Noel Salas', datetime.date(2001, 12, 30), False, None),
#  (971, 'Sandra', 'Shaikh Jackson', datetime.date(2014, 3, 6), True, None),
#  (972, 'Reginald', 'Rattanasinh Ensley', datetime.date(1987, 8, 15), True, None),
#  (973, 'David', 'Gales Federgreen', datetime.date(1992, 12, 24), False, None),
#  (974, 'Julie', 'Johnson Kramer', datetime.date(1974, 8, 31), True, None),
#  (975, 'William', 'Kelley Ruano', datetime.date(2009, 6, 7), True, None),
#  (976, 'Lucy', 'Arnold Alexander', datetime.date(1993, 12, 18), False, None),
#  (978, 'Gretchen', 'Gonzalez Frost', datetime.date(1971, 10, 4), True, None),
#  (979, 'Michael', 'Craven Lampley', datetime.date(2019, 5, 20), True, None),
#  (980, 'Sarah', 'Rabren Jewell', datetime.date(1975, 4, 29), True, None),
#  (982, 'Diane', 'Copes Whitmore', datetime.date(1972, 3, 20), True, None),
#  (983, 'Leland', 'Delahoussaye Sutton', datetime.date(2006, 6, 15), True, None),
#  (984, 'Amparo', 'Rodriguez Lopez', datetime.date(2015, 4, 27), False, None),
#  (985, 'Cory', 'Schultz Coursey', datetime.date(1997, 12, 24), True, None),
#  (986, 'Marlon', 'Hale Powell', datetime.date(2006, 2, 26), True, None),
#  (987, 'Deidre', 'Parrow Lee', datetime.date(2018, 11, 24), False, None),
#  (989, 'Michael', 'Howell Skinner', datetime.date(2003, 1, 31), False, None),
#  (990, 'Adam', 'Nichols Gordon', datetime.date(2010, 5, 22), False, None),
#  (991, 'Nancy', 'Nichols Dunbar', datetime.date(2008, 11, 29), True, None),
#  (992, 'Bennie', 'Wells Mills', datetime.date(1994, 9, 18), True, None),
#  (994, 'Susan', 'Chaney York', datetime.date(2011, 2, 22), True, None),
#  (995, 'Jackie', 'Kamerer Adkins', datetime.date(2012, 4, 21), False, None),
#  (996, 'Roger', 'Dixon Snodgrass', datetime.date(2011, 1, 11), False, None),
#  (997, 'Ethel', 'Coleman Grantham', datetime.date(2021, 8, 24), False, None),
#  (998, 'Michael', 'Allen Ballenger', datetime.date(1978, 3, 8), True, None),
#  (999, 'Earl', 'Dozier Ringhouse', datetime.date(1980, 3, 3), True, None),
#  (1000, 'Javier', 'Mcwayne Miller', datetime.date(1980, 4, 26), False, None),
#  (411, 'Carmelita', 'Peavey Holland', datetime.date(2009, 7, 19), False, 857),
#  (857, 'Angela', 'Spaeth Mitchell', datetime.date(1995, 5, 4), False, 411),
#  (988, 'Margaret', 'Hesson Swann', datetime.date(2022, 5, 29), True, 345),
#  (950, 'Jeffrey', 'Wells Clark', datetime.date(2022, 12, 5), False, 621),
#  (969, 'Elena', 'Flander Miller', datetime.date(2006, 1, 8), True, 68),
#  (947, 'Harold', 'Foust Wilson', datetime.date(1974, 10, 9), False, 981),
#  (993, 'Melissa', 'Markel Hickman', datetime.date(1979, 8, 28), False, 61),
#  (945, 'Glenn', 'Miller Quigley', datetime.date(1975, 6, 30), True, 143),
#  (887, 'Nicholas', 'Plaza Swanner', datetime.date(1974, 1, 1), False, 17),
#  (932, 'Andrea', 'Young Phipps', datetime.date(1985, 11, 15), True, 900),
#  (900, 'Gary', 'Jackson Hebert', datetime.date(1997, 9, 10), True, 932),
#  (919, 'Micheal', 'Mayfield Timms', datetime.date(1977, 7, 7), False, 408),
#  (927, 'Herbert', 'Johnson Powers', datetime.date(1988, 10, 10), True, 184),
#  (913, 'Grace', 'Little Barker', datetime.date(1990, 9, 18), True, 752),
#  (963, 'Martha', 'Jones Buzis', datetime.date(1989, 6, 29), True, 268),
#  (956, 'Jose', 'Weintraub Branscum', datetime.date(1971, 3, 26), True, 866),
#  (977, 'Janet', 'Goins Shade', datetime.date(2003, 11, 14), False, 957),
#  (894, 'Christine', 'Chambers Schulz', datetime.date(2002, 3, 21), False, 596),
#  (892, 'Lee', 'Shelby Varner', datetime.date(1995, 8, 25), False, 545),
#  (938, 'Jane', 'Barocio Barron', datetime.date(1970, 2, 2), False, 515),
#  (905, 'Joaquin', 'Basso Lewis', datetime.date(1994, 8, 7), False, 43),
#  (953, 'Lauryn', 'Breeding Elrod', datetime.date(1971, 9, 17), False, 384),
#  (928, 'Stephen', 'Graig Ziler', datetime.date(1981, 2, 8), True, 142),
#  (271, 'Deborah', 'Patterson Sherman', datetime.date(1997, 3, 23), True, 23),
#  (23, 'Melanie', 'Thompson Matos', datetime.date(2008, 3, 3), False, 271),
#  (25, 'Ernesto', 'Nixon Rivera', datetime.date(2018, 5, 17), False, 640),
#  (640, 'Walter', 'Martin Kitchen', datetime.date(2010, 11, 30), True, 25),
#  (240, 'Bernard', 'Portsche Bourgeois', datetime.date(2003, 7, 15), True, 51),
#  (561, 'Sara', 'Sammer Sabatelli', datetime.date(1989, 10, 20), True, 494),
#  (939, 'Ralph', 'Ashley Caballero', datetime.date(1988, 8, 15), True, 593),
#  (189, 'Frances', 'Boesen Jenkins', datetime.date(2017, 7, 5), True, 266),
#  (834, 'Maria', 'Burch Johnson', datetime.date(1979, 5, 26), False, 867),
#  (745, 'Kevin', 'Hunt Robbins', datetime.date(2006, 8, 13), False, 252),
#  (981, 'Shannon', 'Brown Ratliff', datetime.date(2008, 1, 30), True, 947),
#  (549, 'Pamela', 'Gregg Henderson', datetime.date(1992, 7, 23), True, 614),
#  (705, 'Rebecca', 'Watkins Brownie', datetime.date(2013, 7, 15), False, 744),
#  (493, 'Wendy', 'Bence Sawyer', datetime.date(1984, 11, 10), True, 778),
#  (3, 'Mary', 'Boutwell Dykes', datetime.date(2004, 10, 4), False, 35),
#  (876, 'Kenneth', 'Pawlowski Thomas', datetime.date(1983, 3, 26), True, 785),
#  (86, 'Michael', 'Herrera Black', datetime.date(1989, 11, 26), True, 4),
#  (588, 'James', 'Bowman Mclavrin', datetime.date(2015, 9, 1), True, 601),
#  (242, 'David', 'Brayboy Spurgeon', datetime.date(2020, 10, 9), False, 183),
#  (957, 'Joshua', 'Raymond Waggoner', datetime.date(1994, 6, 1), True, 977),
#  (351, 'Kevin', 'Mitchell Conway', datetime.date(1972, 10, 11), True, 829),
#  (424, 'Jeannette', 'Cornish Anderson', datetime.date(1978, 8, 26), True, 208),
#  (870, 'Marjorie', 'Reyes Jackson', datetime.date(2022, 11, 28), False, 182),
#  (510, 'Rachel', 'Lee Weiss', datetime.date(2022, 4, 3), False, 622),
#  (500, 'Linda', 'Dulac Brown', datetime.date(1994, 3, 25), True, 407)]

# %% [markdown]
# ### Consulta 2 (6 pts)
# **Cantidad de personas nacidas después del inicio de la pandemia.**(inicio de la pandemia 01-12-2019)
#
# Ejemplo:
#
#
# | Cantidad     |
# |--------------|
# | 292 |
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
#
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */
#
# SELECT
#     *
# FROM
#     *

# %% [markdown]
# ### Consulta 3 (6 pts)
# **ID, nombre, apellidos y saldo total de todas las personas**( Limitar a 20 filas para visualizar)
#
# Ejemplo:
#
# | ID    | Nombre | Apellido | Dinero |
# |----------------|--------|-|-|
# | 13 | Tommy | Miller | 12501 |
# | ... | ... | ... | ... |
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
#
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */
#
# SELECT
#     *
# FROM
#     *

# %% [markdown]
# ### Consulta 4 (6 pts)
# **Nombre de la Facción y la cantidad de trabajadores activos hasta fecha X.**
#
# Ejemplo:
#
# | Facción     | Cantidad de trabajadores |
# |----------------|--------|
# | FEDRA | 1273 |
# | Luciérnagas | 121 |
# | Carroñeros  | 72 |
# | ...  | ... |
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
#
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */
#
# SELECT
#     *
# FROM
#     *

# %% [markdown]
# ### Consulta 5 (6 pts)
# **Nombre de la Facción y su cantidad de personas infectadas.**
#
# Ejemplo:
#
# |  Facción  | Personas infectadas |
# |--------|-------|
# | FEDRA | 251 |
# | Luciérnagas | 17 |
# | Carroñeros  | 12 |
# | ...  | ... |
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
#
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */
#
# SELECT
#     *
# FROM
#     *

# %% [markdown]
# ### Consulta 6 (6 pts)
# **Nombre de la Facción y su trabajo más realizado.**
#
# Ejemplo:
#
# |  Facción  | Trabajo |
# |--------|-------|
# | FEDRA | Limpiador de cloacas |
# | Luciérnagas | Médico |
# | Carroñeros  | Explorador |
# | ...  | ... |
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
#
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */
#
# SELECT
#     *
# FROM
#     *

# %% [markdown]
# ### Consulta 7 (8 pts)
# **Nombre de la Facción y su Saldo total** (Es decir, la suma total de los saldos de cada persona perteneciente a la facción.)
#
# Ejemplo:
#
# |Facción | Saldo |
# |--------|-|
# | FEDRA | 523000 |
# | Luciérnagas | 130023 |
# | Carroñeros  | 17432 |
# | ...  | ...|
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
#
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */
#
# %%sql
# SELECT
#     *
# FROM
#     *

# %% [markdown]
# ### Consulta 8 (6 pts)
# **Nombre del Banco, cantidad de usuarios pertenecientes al banco y saldo total del banco.**
#
# ###### Es decir, todos los bancos que ocupan los habitantes de cada faccion
#
# Ejemplo:
#
# |Banco | Cantidad|Saldo|
# |----|---|---|
# |FedraBank S.A |321|20000|
# |Banco Pedrito Pascal SpA  |21|200|
# | Banco De Chile|213|56000|
# | ... | ... |
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
#
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */
#
# %%sql
# SELECT
#     *
# FROM
#     *

# %% [markdown]
# ### Consulta 9 (8 pts)
# **Nombre de la Facción y el Banco más utilizado por sus habitantes**(Si hay empate, que se muestre solo uno.)
#
# Ejemplo:
#
# |Facción | Banco |
# | - | - |
# | FEDRA | FedraBank S.A |
# | Luciérnagas | Banco Pedrito Pascal SpA |
# | ... | ... |
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
#
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */
#
# %%sql
# SELECT
#     *
# FROM
#     *

# %% [markdown]
# ### Consulta 10 (6 pts)
# **ID, nombre y segundo apellido de las personas traidoras**(Es decir, si la persona pertenece a dos o más facciones.)
#
# Ejemplo:
#
# |ID | Nombre | Apellido |
# |-|-------|-|
# | 1 | Pedro | Pascal |
# | 2 | Bella | Ramsey |
# | ... | ... | ... |
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
#
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */
#
# %%sql
# SELECT
#     *
# FROM
#     *

# %% [markdown]
# ### Consulta BONUS (6 pts.)
#
# **Nombre y Apellidos de las personas casadas**(solo se muestra una única vez la pareja)
#
# Ejemplo:
#
# |Nombre persona 1 | Apellidos persona 1 | Nombre persona 2 | Apellidos persona 2 |
# |-|-------|-|-|
# | Felipe | Martinez | Raul | Cuello |
# | Rodrigo | Munita | Juan | Mira |
# | Nicole | Rojel | Benjamin | Campos |
# | ... | ... | ... | ... |
#
# **Solución:** _Escriba aquí la descripción de su solución._

# %%
# %%sql
#
# /* Reemplace estas queries por las que resuelven las consultas pedidas. */
#
# %%sql
# SELECT
#     *
# FROM
#     *
